# %% [markdown]
# # Web Scraping

# %%
from IPython.display import HTML
import numpy as np
import urllib.request
import bs4
import time
import operator
import socket
import re
from bs4 import BeautifulSoup
import requests
from pandas import Series
import pandas as pd
from pandas import DataFrame
import datetime
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import csv

import matplotlib
import matplotlib.pyplot as plt

from collections import Counter

# %matplotlib inline

import seaborn as sns
sns.set_context("poster")
sns.set_style("white")

# %%
import sys
print(sys.path)  # to install webdriver
# Out:
# ['D:\\Files\\Learning Materials\\Y4\\INT303-BigDataAnalytics\\Assignment', 'D:\\Software\\Anaconda\\anaconda1\\python38.zip', 'D:\\Software\\Anaconda\\anaconda1\\DLLs', 'D:\\Software\\Anaconda\\anaconda1\\lib', 'D:\\Software\\Anaconda\\anaconda1', '', 'D:\\Software\\Anaconda\\anaconda1\\lib\\site-packages', 'D:\\Software\\Anaconda\\anaconda1\\lib\\site-packages\\win32', 'D:\\Software\\Anaconda\\anaconda1\\lib\\site-packages\\win32\\lib', 'D:\\Software\\Anaconda\\anaconda1\\lib\\site-packages\\Pythonwin', 'D:\\Software\\Anaconda\\anaconda1\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\Stanley\\.ipython']

# %%
def scrapWeb(url):
    browser = webdriver.Chrome()
    browser.get(url)

    # wait until the page loads
    wait = WebDriverWait(browser, 10)
    wait.until_not(EC.presence_of_element_located((By.CLASS_NAME, "grid")))

    soup = BeautifulSoup(browser.page_source, "html.parser")
    browser.close()
    return soup

# %%
moives = []
for page in range(0, 100, 10):
    url = 'https://maoyan.com/board/4?offset=' + str(page)
    result = scrapWeb(url)
    print(result)
    pattern = re.compile('<dd>.*?board-index.*?>(\d+)</i>.*?name.*?href="(.*?)".*?title="(.*?)".*?star'
                         +'.*?主演：(.*?)</p>.*?releasetime.*?上映时间：(\d{4}-\d{1,2}-\d{1,2}|\d{4})'
                         +'.*?</p>.*?"integer">(.*?)</i>.*?fraction">(.*?)</i>.*?</dd>', re.S)
    contents = re.findall(pattern, str(result))
#     print(contents)
    moives += contents
    print(moives)
    time.sleep(1)
# Out:
# <html><!--<![endif]--><head>
# <title>TOP100榜 - 猫眼电影 - 一网打尽好电影</title>
# <link href="//p0.meituan.net" rel="dns-prefetch"/>
# <link href="//p1.meituan.net" rel="dns-prefetch"/>
# <link href="//ms0.meituan.net" rel="dns-prefetch"/>
# <link href="//s0.meituan.net" rel="dns-prefetch"/>
# <link href="//ms1.meituan.net" rel="dns-prefetch"/>
# <link href="//analytics.meituan.com" rel="dns-prefetch"/>
# <link href="//report.meituan.com" rel="dns-prefetch"/>
# <link href="//frep.meituan.com" rel="dns-prefetch"/>
# <meta charset="utf-8"/>
# <meta content="猫眼电影,电影排行榜,热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100" name="keywords"/>
# <meta content="猫眼电影热门榜单,包括热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100,多维度为用户进行选片决策" name="description"/>
# <meta content="yes" http-equiv="cleartype"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="webkit" name="renderer"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="email=no" name="format-detection"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script async="" src="https://s0.meituan.net/bs/js/?f=mta-js:mta.min.js"></script><script src="https://hm.baidu.com/hm.js?703e94591e87be68cc8da0da7cbd0be2"></script><script>"use strict";!function(){var i=0<arguments.length&&void 0!==arguments[0]?arguments[0]:"_Owl_",n=window;n[i]||(n[i]={isRunning:!1,isReady:!1,preTasks:[],dataSet:[],use:function(i,t){this.isReady&&n.Owl&&n.Owl[i](t),this.preTasks.push({api:i,data:[t]})},add:function(i){this.dataSet.push(i)},run:function(){var t=this;if(!this.isRunning){this.isRunning=!0;var i=n.onerror;n.onerror=function(){this.isReady||this.add({type:"jsError",data:arguments}),i&&i.apply(n,arguments)}.bind(this),(n.addEventListener||n.attachEvent)("error",function(i){t.isReady||t.add({type:"resError",data:[i]})},!0)}}},n[i].run())}();</script>
# <script>
#   cid = "c_wx6zb55";
#   ci = 80;
# val = {"subnavId":4};    window.system = {};
#
#   window.openPlatform = '';
#   window.openPlatformSub = '';
#   window.$mtsiFlag = '0';
#   window.NODE_ENV = 'production';
#
#   </script>
# <link href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/common.6b1d782c.css" rel="stylesheet"/>
# <link href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/board-index.92a06072.css" rel="stylesheet"/>
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/stat.88d57c80.js"></script><script async="" charset="utf-8" defer="" src="//analytics.meituan.com/source/stable/web.js"></script>
# <script>if(window.devicePixelRatio >= 2) { document.write('<link rel="stylesheet" href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image-2x.8ba7074d.css"/>') }</script>
# <style>
#     @font-face {
#       font-family: stonefont;
#       src: url('//vfile.meituan.net/colorstone/5520e321491e9e30655b24d1e6f495083424.eot');
#       src: url('//vfile.meituan.net/colorstone/5520e321491e9e30655b24d1e6f495083424.eot?#iefix') format('embedded-opentype'),
#            url('//vfile.meituan.net/colorstone/a455321dd245433644557ef0bfe33b1b2280.woff') format('woff');
#     }
#
#     .stonefont {
#       font-family: stonefont;
#     }
#   </style>
# <script>
#   var _hmt = _hmt || [];
#   (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?703e94591e87be68cc8da0da7cbd0be2";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
#   })();
#   </script>
# <meta content="off" from="v3api" name="lx:autopv"/><meta content="movie" from="v3api" name="lx:appnm"/><meta content="movie" from="v3api" name="lx:category"/></head>
# <body>
# <div class="header">
# <div class="header-inner">
# <a class="logo" data-act="icon-click" href="//maoyan.com">猫眼电影</a>
# <div class="city-container" data-val="{currentcityid:80 }">
# <div class="city-selected">
# <div class="city-name">
#                   苏州
#                   <span class="caret"></span>
# </div>
# </div>
# <div class="city-list" data-val="{ localcityid: 80 }">
# <div class="city-list-header">定位城市：<a class="js-geo-city" data-ci="80">苏州</a></div>
# </div>
# </div>
# <div class="nav">
# <ul class="navbar">
# <li><a data-act="home-click" href="/">首页</a></li>
# <li><a data-act="movies-click" href="/films">电影</a></li>
# <li><a data-act="cinemas-click" href="/cinemas">影院</a></li>
# <li><a href="http://www.gewara.com">演出</a></li>
# <li><a class="active" data-act="board-click" href="/board">榜单</a></li>
# <li><a data-act="hotNews-click" href="/news">热点</a></li>
# <li><a href="/edimall">商城</a></li>
# </ul>
# </div>
# <div class="user-info">
# <div class="user-avatar J-login">
# <img src="https://p0.meituan.net/movie/7dd82a16316ab32c8359debdb04396ef2897.png"/>
# <span class="caret"></span>
# <ul class="user-menu no-login-menu">
# <li><a href="javascript:void 0">登录</a></li>
# </ul>
# </div>
# </div>
# <form action="/query" class="search-form" data-actform="search-click" target="_blank">
# <input autocomplete="off" class="search" maxlength="32" name="kw" placeholder="找影视剧、影人、影院" type="search"/>
# <input class="submit" type="submit" value=""/>
# </form>
# <div class="app-download">
# <a href="/app" target="_blank">
# <span class="iphone-icon"></span>
# <span class="apptext">APP下载</span>
# <span class="caret"></span>
# <div class="download-icon">
# <p class="down-title">扫码下载APP</p>
# <p class="down-content">选座更优惠</p>
# </div>
# </a>
# </div>
# </div>
# </div>
# <div class="header-placeholder"></div>
# <div class="subnav">
# <ul class="navbar">
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:7}" href="/board/7">热映口碑榜</a>
# </li>
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:6}" href="/board/6">最受期待榜</a>
# </li>
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:1}" href="/board/1">国内票房榜</a>
# </li>
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:2}" href="/board/2">北美票房榜</a>
# </li>
# <li>
# <a class="active" data-act="subnav-click" data-state-val="{subnavId:4}" data-val="{subnavClick:4}" href="javascript:void(0);">TOP100榜</a>
# </li>
# </ul>
# </div>
# <div class="container" id="app">
# <div class="content">
# <div class="wrapper">
# <div class="main">
# <p class="update-time">2021-10-26<span class="has-fresh-text">已更新</span></p>
# <p class="board-content">榜单规则：将猫眼电影库中的经典影片，按照评分和评分人数从高到低综合排序取前100名，每天上午10点更新。相关数据来源于“猫眼电影库”。</p>
# <dl class="board-wrapper">
# <dd>
# <i class="board-index board-index-1">1</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1200486}" href="/films/1200486" title="我不是药神">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="我不是药神" class="board-img" data-src="https://p0.meituan.net/movie/414176cfa3fea8bed9b579e9f42766b9686649.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1200486}" href="/films/1200486" title="我不是药神">我不是药神</a></p>
# <p class="star">
#                 主演：徐峥,周一围,王传君
#         </p>
# <p class="releasetime">上映时间：2018-07-05</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">6</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-2">2</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1297}" href="/films/1297" title="肖申克的救赎">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="肖申克的救赎" class="board-img" data-src="https://p0.meituan.net/movie/8112a8345d7f1d807d026282f2371008602126.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1297}" href="/films/1297" title="肖申克的救赎">肖申克的救赎</a></p>
# <p class="star">
#                 主演：蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿
#         </p>
# <p class="releasetime">上映时间：1994-09-10(加拿大)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">5</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-3">3</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1206605}" href="/films/1206605" title="绿皮书">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="绿皮书" class="board-img" data-src="https://p1.meituan.net/movie/c9b280de01549fcb71913edec05880585769972.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1206605}" href="/films/1206605" title="绿皮书">绿皮书</a></p>
# <p class="star">
#                 主演：维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼
#         </p>
# <p class="releasetime">上映时间：2019-03-01</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">5</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-4">4</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1292}" href="/films/1292" title="海上钢琴师">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="海上钢琴师" class="board-img" data-src="https://p0.meituan.net/movie/609e45bd40346eb8b927381be8fb27a61760914.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1292}" href="/films/1292" title="海上钢琴师">海上钢琴师</a></p>
# <p class="star">
#                 主演：蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世
#         </p>
# <p class="releasetime">上映时间：2019-11-15</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">3</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-5">5</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1211270}" href="/films/1211270" title="哪吒之魔童降世">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="哪吒之魔童降世" class="board-img" data-src="https://p0.meituan.net/movie/005955214d5b3e50c910d7a511b0cb571445301.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1211270}" href="/films/1211270" title="哪吒之魔童降世">哪吒之魔童降世</a></p>
# <p class="star">
#                 主演：吕艳婷,囧森瑟夫,瀚墨
#         </p>
# <p class="releasetime">上映时间：2019-07-26</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">6</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-6">6</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1203}" href="/films/1203" title="霸王别姬">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="霸王别姬" class="board-img" data-src="https://p0.meituan.net/movie/61fea77024f83b3700603f6af93bf690585789.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1203}" href="/films/1203" title="霸王别姬">霸王别姬</a></p>
# <p class="star">
#                 主演：张国荣,张丰毅,巩俐
#         </p>
# <p class="releasetime">上映时间：1993-07-26</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">4</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-7">7</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1216365}" href="/films/1216365" title="小偷家族">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="小偷家族" class="board-img" data-src="https://p1.meituan.net/movie/ac8f0004928fbce5a038a007b7c73cec746794.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1216365}" href="/films/1216365" title="小偷家族">小偷家族</a></p>
# <p class="star">
#                 主演：中川雅也,安藤樱,松冈茉优
#         </p>
# <p class="releasetime">上映时间：2018-08-03</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">1</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-8">8</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1303}" href="/films/1303" title="美丽人生">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="美丽人生" class="board-img" data-src="https://p1.meituan.net/movie/580d81a2c78bf204f45323ddb4244b6c6821175.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1303}" href="/films/1303" title="美丽人生">美丽人生</a></p>
# <p class="star">
#                 主演：罗伯托·贝尼尼,朱斯蒂诺·杜拉诺,赛尔乔·比尼·布斯特里克
#         </p>
# <p class="releasetime">上映时间：2020-01-03</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">3</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-9">9</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:4055}" href="/films/4055" title="这个杀手不太冷">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="这个杀手不太冷" class="board-img" data-src="https://p1.meituan.net/movie/6bea9af4524dfbd0b668eaa7e187c3df767253.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:4055}" href="/films/4055" title="这个杀手不太冷">这个杀手不太冷</a></p>
# <p class="star">
#                 主演：让·雷诺,加里·奥德曼,娜塔莉·波特曼
#         </p>
# <p class="releasetime">上映时间：1994-09-14(法国)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">4</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-10">10</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:416}" href="/films/416" title="盗梦空间">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="盗梦空间" class="board-img" data-src="https://p0.meituan.net/moviemachine/c2496a7290a72eac6081321898c347693550574.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:416}" href="/films/416" title="盗梦空间">盗梦空间</a></p>
# <p class="star">
#                 主演：莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特
#         </p>
# <p class="releasetime">上映时间：2010-09-01</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">0</i></p>
# </div>
# </div>
# </div>
# </dd>
# </dl>
# </div>
# <div class="pager-main">
# <ul class="list-pager">
# <li class="active">
# <a class="page_1" href="javascript:void(0);" style="cursor: default">1</a>
# </li>
# <li>
# <a class="page_2" href="?offset=10">2</a>
# </li>
# <li>
# <a class="page_3" href="?offset=20">3</a>
# </li>
# <li>
# <a class="page_4" href="?offset=30">4</a>
# </li>
# <li>
# <a class="page_5" href="?offset=40">5</a>
# </li>
# <li class="sep">...</li>
# <li>
# <a class="page_10" href="?offset=90">10</a>
# </li>
# <li> <a class="page_2" href="?offset=10">下一页</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footer" style="visibility: visible;">
# <p class="friendly-links">
#     关于猫眼 :
#     <a href="http://ir.maoyan.com/s/index.php#pageScroll0" target="_blank">关于我们</a>
# <span></span>
# <a href="http://ir.maoyan.com/s/index.php#pageScroll1" target="_blank">管理团队</a>
# <span></span>
# <a href="http://ir.maoyan.com/s/index.php#pageScroll2" target="_blank">投资者关系</a>
#
#     友情链接 :
#     <a data-query="utm_source=wwwmaoyan" href="http://www.meituan.com" target="_blank">美团网</a>
# <span></span>
# <a data-query="utm_source=wwwmaoyan" href="http://www.gewara.com">格瓦拉</a>
# <span></span>
# <a data-query="utm_source=wwwmaoyan" href="http://i.meituan.com/client" target="_blank">美团下载</a>
# <span></span>
# <a data-query="utm_source=maoyan_pc" href="https://www.huanxi.com" target="_blank">欢喜首映</a>
# </p>
# <p class="friendly-links">
#     商务合作邮箱：v@maoyan.com
#     客服电话：10105335
#     违法和不良信息/涉未成年人有害信息举报电话：4006018900
#   </p>
# <p class="friendly-links">
#     用户举报/涉未成年人有害信息举报邮箱：tousujubao@meituan.com
#     舞弊线索举报邮箱：wubijubao@maoyan.com
#   </p>
# <p class="friendly-links credentials">
# <a href="/about/licence/1" target="_blank">中华人民共和国增值电信业务经营许可证 京B2-20190350</a>
# <span></span>
# <a href="/about/licence/4" target="_blank">营业性演出许可证 京演（机构）（2019）4094号</a>
# </p>
# <p class="friendly-links credentials">
# <a href="/about/licence/3" target="_blank">广播电视节目制作经营许可证 （京）字第08478号</a>
# <span></span>
# <a href="/about/licence/2" target="_blank">网络文化经营许可证 京网文（2019）3837-369号 </a>
# </p>
# <p class="friendly-links credentials">
# <a href="/rules/agreement" target="_blank">猫眼用户服务协议 </a>
# <span></span>
# <a href="/rules/rule" target="_blank">猫眼平台交易规则总则 </a>
# <span></span>
# <a href="/rules/privacy" target="_blank">隐私政策 </a>
# </p>
# <p class="friendly-links credentials">
# <a href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=11010102003232" target="_blank">京公网安备
#       11010102003232号</a>
# <span></span>
# <a href="http://beian.miit.gov.cn/" target="_blank">京ICP备16022489号-1</a>
# </p>
# <p>北京猫眼文化传媒有限公司</p>
# <p>
#     ©<span class="my-footer-year">2021</span>
#     猫眼电影 maoyan.com</p>
# <div class="certificate">
# <a href="http://sq.ccm.gov.cn:80/ccnt/sczr/service/business/emark/toDetail/350CF8BCA8416C4FE0530140A8C0957E" target="_blank">
# <img src="https://p0.meituan.net/moviemachine/e54374ccf134d1f7b2c5b075a74fca525326.png"/>
# </a>
# <a href="/about/licence/5" target="_blank">
# <img src="https://p1.meituan.net/moviemachine/805f605d5cf1b1a02a4e3a5e29df003b8376.png"/>
# </a>
# <a href="https://www.12377.cn" target="_blank">
# <img src="https://p0.meituan.net/scarlett/3cd2a9b7dc179531d20d27a5fd686e783787.png"/>
# </a>
# </div>
# </div>
# <script crossorigin="anonymous" src="//www.dpfile.com/app/owl/static/owl_1.7.11.js"></script>
# <script>
#       Owl.start({
#         project: 'com.sankuai.movie.fe.mywww',
#         pageUrl: location.href.split('?')[0].replace(/\/\d+/g, '/:id'),
#         devMode: false
#       })
#     </script>
# <!--[if IE 8]><script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/es5-shim.bbad933f.js"></script><![endif]-->
# <!--[if IE 8]><script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/es5-sham.d6ea26f4.js"></script><![endif]-->
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/common.c5e8f9fe.js"></script>
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/board-index.be8ae70e.js"></script>
# </body></html>
# [('1', '/films/1200486', '我不是药神', '徐峥,周一围,王传君\n        ', '2018-07-05', '9.', '6'), ('2', '/films/1297', '肖申克的救赎', '蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿\n        ', '1994-09-10', '9.', '5'), ('3', '/films/1206605', '绿皮书', '维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼\n        ', '2019-03-01', '9.', '5'), ('4', '/films/1292', '海上钢琴师', '蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世\n        ', '2019-11-15', '9.', '3'), ('5', '/films/1211270', '哪吒之魔童降世', '吕艳婷,囧森瑟夫,瀚墨\n        ', '2019-07-26', '9.', '6'), ('6', '/films/1203', '霸王别姬', '张国荣,张丰毅,巩俐\n        ', '1993-07-26', '9.', '4'), ('7', '/films/1216365', '小偷家族', '中川雅也,安藤樱,松冈茉优\n        ', '2018-08-03', '8.', '1'), ('8', '/films/1303', '美丽人生', '罗伯托·贝尼尼,朱斯蒂诺·杜拉诺,赛尔乔·比尼·布斯特里克\n        ', '2020-01-03', '9.', '3'), ('9', '/films/4055', '这个杀手不太冷', '让·雷诺,加里·奥德曼,娜塔莉·波特曼\n        ', '1994-09-14', '9.', '4'), ('10', '/films/416', '盗梦空间', '莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特\n        ', '2010-09-01', '9.', '0')]
# <html><!--<![endif]--><head>
# <title>TOP100榜 - 猫眼电影 - 一网打尽好电影</title>
# <link href="//p0.meituan.net" rel="dns-prefetch"/>
# <link href="//p1.meituan.net" rel="dns-prefetch"/>
# <link href="//ms0.meituan.net" rel="dns-prefetch"/>
# <link href="//s0.meituan.net" rel="dns-prefetch"/>
# <link href="//ms1.meituan.net" rel="dns-prefetch"/>
# <link href="//analytics.meituan.com" rel="dns-prefetch"/>
# <link href="//report.meituan.com" rel="dns-prefetch"/>
# <link href="//frep.meituan.com" rel="dns-prefetch"/>
# <meta charset="utf-8"/>
# <meta content="猫眼电影,电影排行榜,热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100" name="keywords"/>
# <meta content="猫眼电影热门榜单,包括热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100,多维度为用户进行选片决策" name="description"/>
# <meta content="yes" http-equiv="cleartype"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="webkit" name="renderer"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="email=no" name="format-detection"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script async="" src="https://s0.meituan.net/bs/js/?f=mta-js:mta.min.js"></script><script src="https://hm.baidu.com/hm.js?703e94591e87be68cc8da0da7cbd0be2"></script><script>"use strict";!function(){var i=0<arguments.length&&void 0!==arguments[0]?arguments[0]:"_Owl_",n=window;n[i]||(n[i]={isRunning:!1,isReady:!1,preTasks:[],dataSet:[],use:function(i,t){this.isReady&&n.Owl&&n.Owl[i](t),this.preTasks.push({api:i,data:[t]})},add:function(i){this.dataSet.push(i)},run:function(){var t=this;if(!this.isRunning){this.isRunning=!0;var i=n.onerror;n.onerror=function(){this.isReady||this.add({type:"jsError",data:arguments}),i&&i.apply(n,arguments)}.bind(this),(n.addEventListener||n.attachEvent)("error",function(i){t.isReady||t.add({type:"resError",data:[i]})},!0)}}},n[i].run())}();</script>
# <script>
#   cid = "c_wx6zb55";
#   ci = 80;
# val = {"subnavId":4};    window.system = {};
#
#   window.openPlatform = '';
#   window.openPlatformSub = '';
#   window.$mtsiFlag = '0';
#   window.NODE_ENV = 'production';
#
#   </script>
# <link href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/common.6b1d782c.css" rel="stylesheet"/>
# <link href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/board-index.92a06072.css" rel="stylesheet"/>
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/stat.88d57c80.js"></script><script async="" charset="utf-8" defer="" src="//analytics.meituan.com/source/stable/web.js"></script>
# <script>if(window.devicePixelRatio >= 2) { document.write('<link rel="stylesheet" href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image-2x.8ba7074d.css"/>') }</script>
# <style>
#     @font-face {
#       font-family: stonefont;
#       src: url('//vfile.meituan.net/colorstone/b003db2a0e95c0c661ed928fa3d54c1b3440.eot');
#       src: url('//vfile.meituan.net/colorstone/b003db2a0e95c0c661ed928fa3d54c1b3440.eot?#iefix') format('embedded-opentype'),
#            url('//vfile.meituan.net/colorstone/630a2e5b1d4a143233460aea6297d90d2264.woff') format('woff');
#     }
#
#     .stonefont {
#       font-family: stonefont;
#     }
#   </style>
# <script>
#   var _hmt = _hmt || [];
#   (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?703e94591e87be68cc8da0da7cbd0be2";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
#   })();
#   </script>
# <meta content="off" from="v3api" name="lx:autopv"/><meta content="movie" from="v3api" name="lx:appnm"/><meta content="movie" from="v3api" name="lx:category"/></head>
# <body>
# <div class="header">
# <div class="header-inner">
# <a class="logo" data-act="icon-click" href="//maoyan.com">猫眼电影</a>
# <div class="city-container" data-val="{currentcityid:80 }">
# <div class="city-selected">
# <div class="city-name">
#                   苏州
#                   <span class="caret"></span>
# </div>
# </div>
# <div class="city-list" data-val="{ localcityid: 80 }">
# <div class="city-list-header">定位城市：<a class="js-geo-city" data-ci="80">苏州</a></div>
# </div>
# </div>
# <div class="nav">
# <ul class="navbar">
# <li><a data-act="home-click" href="/">首页</a></li>
# <li><a data-act="movies-click" href="/films">电影</a></li>
# <li><a data-act="cinemas-click" href="/cinemas">影院</a></li>
# <li><a href="http://www.gewara.com">演出</a></li>
# <li><a class="active" data-act="board-click" href="/board">榜单</a></li>
# <li><a data-act="hotNews-click" href="/news">热点</a></li>
# <li><a href="/edimall">商城</a></li>
# </ul>
# </div>
# <div class="user-info">
# <div class="user-avatar J-login">
# <img src="https://p0.meituan.net/movie/7dd82a16316ab32c8359debdb04396ef2897.png"/>
# <span class="caret"></span>
# <ul class="user-menu no-login-menu">
# <li><a href="javascript:void 0">登录</a></li>
# </ul>
# </div>
# </div>
# <form action="/query" class="search-form" data-actform="search-click" target="_blank">
# <input autocomplete="off" class="search" maxlength="32" name="kw" placeholder="找影视剧、影人、影院" type="search"/>
# <input class="submit" type="submit" value=""/>
# </form>
# <div class="app-download">
# <a href="/app" target="_blank">
# <span class="iphone-icon"></span>
# <span class="apptext">APP下载</span>
# <span class="caret"></span>
# <div class="download-icon">
# <p class="down-title">扫码下载APP</p>
# <p class="down-content">选座更优惠</p>
# </div>
# </a>
# </div>
# </div>
# </div>
# <div class="header-placeholder"></div>
# <div class="subnav">
# <ul class="navbar">
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:7}" href="/board/7">热映口碑榜</a>
# </li>
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:6}" href="/board/6">最受期待榜</a>
# </li>
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:1}" href="/board/1">国内票房榜</a>
# </li>
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:2}" href="/board/2">北美票房榜</a>
# </li>
# <li>
# <a class="active" data-act="subnav-click" data-state-val="{subnavId:4}" data-val="{subnavClick:4}" href="javascript:void(0);">TOP100榜</a>
# </li>
# </ul>
# </div>
# <div class="container" id="app">
# <div class="content">
# <div class="wrapper">
# <div class="main">
# <p class="update-time">2021-10-26<span class="has-fresh-text">已更新</span></p>
# <p class="board-content">榜单规则：将猫眼电影库中的经典影片，按照评分和评分人数从高到低综合排序取前100名，每天上午10点更新。相关数据来源于“猫眼电影库”。</p>
# <dl class="board-wrapper">
# <dd>
# <i class="board-index board-index-11">11</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1633}" href="/films/1633" title="阿甘正传">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="阿甘正传" class="board-img" data-src="https://p0.meituan.net/movie/b41795c4a88479137e40ebdc3d7dc040238291.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1633}" href="/films/1633" title="阿甘正传">阿甘正传</a></p>
# <p class="star">
#                 主演：汤姆·汉克斯,罗宾·怀特,加里·西尼斯
#         </p>
# <p class="releasetime">上映时间：1994-07-06(美国)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">4</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-12">12</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1212}" href="/films/1212" title="千与千寻">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="千与千寻" class="board-img" data-src="https://p0.meituan.net/movie/30b20139e68c46d02e0893277d633b701292458.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1212}" href="/films/1212" title="千与千寻">千与千寻</a></p>
# <p class="star">
#                 主演：柊瑠美,周冬雨,入野自由
#         </p>
# <p class="releasetime">上映时间：2019-06-21</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">3</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-13">13</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:78341}" href="/films/78341" title="星际穿越">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="星际穿越" class="board-img" data-src="https://p0.meituan.net/moviemachine/94138dc0290a74b35786b6e3b8ece8607940668.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:78341}" href="/films/78341" title="星际穿越">星际穿越</a></p>
# <p class="star">
#                 主演：马修·麦康纳,安妮·海瑟薇,杰西卡·查斯坦
#         </p>
# <p class="releasetime">上映时间：2014-11-12</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">3</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-14">14</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1304}" href="/films/1304" title="楚门的世界">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="楚门的世界" class="board-img" data-src="https://p0.meituan.net/movie/59c05effc4755c627901fb7e044d071d851055.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1304}" href="/films/1304" title="楚门的世界">楚门的世界</a></p>
# <p class="star">
#                 主演：金·凯瑞,劳拉·琳妮,诺亚·艾默里奇
#         </p>
# <p class="releasetime">上映时间：1998(罗马尼亚)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">9</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-15">15</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:70976}" href="/films/70976" title="触不可及">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="触不可及" class="board-img" data-src="https://p0.meituan.net/moviemachine/eb5e33480a3d3b0f813673a33eb556381148211.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:70976}" href="/films/70976" title="触不可及">触不可及</a></p>
# <p class="star">
#                 主演：弗朗索瓦·克鲁塞,奥玛·希,安娜·勒尼
#         </p>
# <p class="releasetime">上映时间：2011-11-02(法国)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">1</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-16">16</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:3667}" href="/films/3667" title="辛德勒的名单">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="辛德勒的名单" class="board-img" data-src="https://p0.meituan.net/movie/b0d986a8bf89278afbb19f6abaef70f31206570.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:3667}" href="/films/3667" title="辛德勒的名单">辛德勒的名单</a></p>
# <p class="star">
#                 主演：连姆·尼森,拉尔夫·费因斯,本·金斯利
#         </p>
# <p class="releasetime">上映时间：1993-11-30(美国)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">2</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-17">17</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1319}" href="/films/1319" title="情书">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="情书" class="board-img" data-src="https://p0.meituan.net/moviemachine/8503c98fa2a02df648f6a59448c4c99078837.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1319}" href="/films/1319" title="情书">情书</a></p>
# <p class="star">
#                 主演：中山美穗,丰川悦司,酒井美纪
#         </p>
# <p class="releasetime">上映时间：1999-03-01</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">9</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-18">18</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:342068}" href="/films/342068" title="寻梦环游记">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="寻梦环游记" class="board-img" data-src="https://p0.meituan.net/movie/f433a705dd26d96e95ba6582ddccf5ad1159253.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:342068}" href="/films/342068" title="寻梦环游记">寻梦环游记</a></p>
# <p class="star">
#                 主演：安东尼·冈萨雷斯,本杰明·布拉特,盖尔·加西亚·贝纳尔
#         </p>
# <p class="releasetime">上映时间：2017-11-24</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">6</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-19">19</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:588362}" href="/films/588362" title="摔跤吧！爸爸">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="摔跤吧！爸爸" class="board-img" data-src="https://p0.meituan.net/movie/aeb864fa21d578d845b9cefc056e40cb2874891.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:588362}" href="/films/588362" title="摔跤吧！爸爸">摔跤吧！爸爸</a></p>
# <p class="star">
#                 主演：阿米尔·汗,沙克希·坦沃,法缇玛·萨那·纱卡
#         </p>
# <p class="releasetime">上映时间：2017-05-05</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">8</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-20">20</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1218727}" href="/films/1218727" title="何以为家">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="何以为家" class="board-img" data-src="https://p1.meituan.net/movie/d28b729ffe72353a72d1e7ef8a9b90591544978.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1218727}" href="/films/1218727" title="何以为家">何以为家</a></p>
# <p class="star">
#                 主演：赞恩·阿尔·拉菲亚,约丹诺斯·希费罗,博鲁瓦蒂夫·特雷杰·班科尔
#         </p>
# <p class="releasetime">上映时间：2019-04-29</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">3</i></p>
# </div>
# </div>
# </div>
# </dd>
# </dl>
# </div>
# <div class="pager-main">
# <ul class="list-pager">
# <li> <a class="page_1" href="?offset=0">上一页</a>
# </li>
# <li>
# <a class="page_1" href="?offset=0">1</a>
# </li>
# <li class="active">
# <a class="page_2" href="javascript:void(0);" style="cursor: default">2</a>
# </li>
# <li>
# <a class="page_3" href="?offset=20">3</a>
# </li>
# <li>
# <a class="page_4" href="?offset=30">4</a>
# </li>
# <li>
# <a class="page_5" href="?offset=40">5</a>
# </li>
# <li class="sep">...</li>
# <li>
# <a class="page_10" href="?offset=90">10</a>
# </li>
# <li> <a class="page_3" href="?offset=20">下一页</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footer" style="visibility: visible;">
# <p class="friendly-links">
#     关于猫眼 :
#     <a href="http://ir.maoyan.com/s/index.php#pageScroll0" target="_blank">关于我们</a>
# <span></span>
# <a href="http://ir.maoyan.com/s/index.php#pageScroll1" target="_blank">管理团队</a>
# <span></span>
# <a href="http://ir.maoyan.com/s/index.php#pageScroll2" target="_blank">投资者关系</a>
#
#     友情链接 :
#     <a data-query="utm_source=wwwmaoyan" href="http://www.meituan.com" target="_blank">美团网</a>
# <span></span>
# <a data-query="utm_source=wwwmaoyan" href="http://www.gewara.com">格瓦拉</a>
# <span></span>
# <a data-query="utm_source=wwwmaoyan" href="http://i.meituan.com/client" target="_blank">美团下载</a>
# <span></span>
# <a data-query="utm_source=maoyan_pc" href="https://www.huanxi.com" target="_blank">欢喜首映</a>
# </p>
# <p class="friendly-links">
#     商务合作邮箱：v@maoyan.com
#     客服电话：10105335
#     违法和不良信息/涉未成年人有害信息举报电话：4006018900
#   </p>
# <p class="friendly-links">
#     用户举报/涉未成年人有害信息举报邮箱：tousujubao@meituan.com
#     舞弊线索举报邮箱：wubijubao@maoyan.com
#   </p>
# <p class="friendly-links credentials">
# <a href="/about/licence/1" target="_blank">中华人民共和国增值电信业务经营许可证 京B2-20190350</a>
# <span></span>
# <a href="/about/licence/4" target="_blank">营业性演出许可证 京演（机构）（2019）4094号</a>
# </p>
# <p class="friendly-links credentials">
# <a href="/about/licence/3" target="_blank">广播电视节目制作经营许可证 （京）字第08478号</a>
# <span></span>
# <a href="/about/licence/2" target="_blank">网络文化经营许可证 京网文（2019）3837-369号 </a>
# </p>
# <p class="friendly-links credentials">
# <a href="/rules/agreement" target="_blank">猫眼用户服务协议 </a>
# <span></span>
# <a href="/rules/rule" target="_blank">猫眼平台交易规则总则 </a>
# <span></span>
# <a href="/rules/privacy" target="_blank">隐私政策 </a>
# </p>
# <p class="friendly-links credentials">
# <a href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=11010102003232" target="_blank">京公网安备
#       11010102003232号</a>
# <span></span>
# <a href="http://beian.miit.gov.cn/" target="_blank">京ICP备16022489号-1</a>
# </p>
# <p>北京猫眼文化传媒有限公司</p>
# <p>
#     ©<span class="my-footer-year">2021</span>
#     猫眼电影 maoyan.com</p>
# <div class="certificate">
# <a href="http://sq.ccm.gov.cn:80/ccnt/sczr/service/business/emark/toDetail/350CF8BCA8416C4FE0530140A8C0957E" target="_blank">
# <img src="https://p0.meituan.net/moviemachine/e54374ccf134d1f7b2c5b075a74fca525326.png"/>
# </a>
# <a href="/about/licence/5" target="_blank">
# <img src="https://p1.meituan.net/moviemachine/805f605d5cf1b1a02a4e3a5e29df003b8376.png"/>
# </a>
# <a href="https://www.12377.cn" target="_blank">
# <img src="https://p0.meituan.net/scarlett/3cd2a9b7dc179531d20d27a5fd686e783787.png"/>
# </a>
# </div>
# </div>
# <script crossorigin="anonymous" src="//www.dpfile.com/app/owl/static/owl_1.7.11.js"></script>
# <script>
#       Owl.start({
#         project: 'com.sankuai.movie.fe.mywww',
#         pageUrl: location.href.split('?')[0].replace(/\/\d+/g, '/:id'),
#         devMode: false
#       })
#     </script>
# <!--[if IE 8]><script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/es5-shim.bbad933f.js"></script><![endif]-->
# <!--[if IE 8]><script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/es5-sham.d6ea26f4.js"></script><![endif]-->
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/common.c5e8f9fe.js"></script>
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/board-index.be8ae70e.js"></script>
# </body></html>
# [('1', '/films/1200486', '我不是药神', '徐峥,周一围,王传君\n        ', '2018-07-05', '9.', '6'), ('2', '/films/1297', '肖申克的救赎', '蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿\n        ', '1994-09-10', '9.', '5'), ('3', '/films/1206605', '绿皮书', '维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼\n        ', '2019-03-01', '9.', '5'), ('4', '/films/1292', '海上钢琴师', '蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世\n        ', '2019-11-15', '9.', '3'), ('5', '/films/1211270', '哪吒之魔童降世', '吕艳婷,囧森瑟夫,瀚墨\n        ', '2019-07-26', '9.', '6'), ('6', '/films/1203', '霸王别姬', '张国荣,张丰毅,巩俐\n        ', '1993-07-26', '9.', '4'), ('7', '/films/1216365', '小偷家族', '中川雅也,安藤樱,松冈茉优\n        ', '2018-08-03', '8.', '1'), ('8', '/films/1303', '美丽人生', '罗伯托·贝尼尼,朱斯蒂诺·杜拉诺,赛尔乔·比尼·布斯特里克\n        ', '2020-01-03', '9.', '3'), ('9', '/films/4055', '这个杀手不太冷', '让·雷诺,加里·奥德曼,娜塔莉·波特曼\n        ', '1994-09-14', '9.', '4'), ('10', '/films/416', '盗梦空间', '莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特\n        ', '2010-09-01', '9.', '0'), ('11', '/films/1633', '阿甘正传', '汤姆·汉克斯,罗宾·怀特,加里·西尼斯\n        ', '1994-07-06', '9.', '4'), ('12', '/films/1212', '千与千寻', '柊瑠美,周冬雨,入野自由\n        ', '2019-06-21', '9.', '3'), ('13', '/films/78341', '星际穿越', '马修·麦康纳,安妮·海瑟薇,杰西卡·查斯坦\n        ', '2014-11-12', '9.', '3'), ('14', '/films/1304', '楚门的世界', '金·凯瑞,劳拉·琳妮,诺亚·艾默里奇\n        ', '1998', '8.', '9'), ('15', '/films/70976', '触不可及', '弗朗索瓦·克鲁塞,奥玛·希,安娜·勒尼\n        ', '2011-11-02', '9.', '1'), ('16', '/films/3667', '辛德勒的名单', '连姆·尼森,拉尔夫·费因斯,本·金斯利\n        ', '1993-11-30', '9.', '2'), ('17', '/films/1319', '情书', '中山美穗,丰川悦司,酒井美纪\n        ', '1999-03-01', '8.', '9'), ('18', '/films/342068', '寻梦环游记', '安东尼·冈萨雷斯,本杰明·布拉特,盖尔·加西亚·贝纳尔\n        ', '2017-11-24', '9.', '6'), ('19', '/films/588362', '摔跤吧！爸爸', '阿米尔·汗,沙克希·坦沃,法缇玛·萨那·纱卡\n        ', '2017-05-05', '9.', '8'), ('20', '/films/1218727', '何以为家', '赞恩·阿尔·拉菲亚,约丹诺斯·希费罗,博鲁瓦蒂夫·特雷杰·班科尔\n        ', '2019-04-29', '9.', '3')]
# <html><!--<![endif]--><head>
# <title>TOP100榜 - 猫眼电影 - 一网打尽好电影</title>
# <link href="//p0.meituan.net" rel="dns-prefetch"/>
# <link href="//p1.meituan.net" rel="dns-prefetch"/>
# <link href="//ms0.meituan.net" rel="dns-prefetch"/>
# <link href="//s0.meituan.net" rel="dns-prefetch"/>
# <link href="//ms1.meituan.net" rel="dns-prefetch"/>
# <link href="//analytics.meituan.com" rel="dns-prefetch"/>
# <link href="//report.meituan.com" rel="dns-prefetch"/>
# <link href="//frep.meituan.com" rel="dns-prefetch"/>
# <meta charset="utf-8"/>
# <meta content="猫眼电影,电影排行榜,热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100" name="keywords"/>
# <meta content="猫眼电影热门榜单,包括热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100,多维度为用户进行选片决策" name="description"/>
# <meta content="yes" http-equiv="cleartype"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="webkit" name="renderer"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="email=no" name="format-detection"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script async="" src="https://s0.meituan.net/bs/js/?f=mta-js:mta.min.js"></script><script src="https://hm.baidu.com/hm.js?703e94591e87be68cc8da0da7cbd0be2"></script><script>"use strict";!function(){var i=0<arguments.length&&void 0!==arguments[0]?arguments[0]:"_Owl_",n=window;n[i]||(n[i]={isRunning:!1,isReady:!1,preTasks:[],dataSet:[],use:function(i,t){this.isReady&&n.Owl&&n.Owl[i](t),this.preTasks.push({api:i,data:[t]})},add:function(i){this.dataSet.push(i)},run:function(){var t=this;if(!this.isRunning){this.isRunning=!0;var i=n.onerror;n.onerror=function(){this.isReady||this.add({type:"jsError",data:arguments}),i&&i.apply(n,arguments)}.bind(this),(n.addEventListener||n.attachEvent)("error",function(i){t.isReady||t.add({type:"resError",data:[i]})},!0)}}},n[i].run())}();</script>
# <script>
#   cid = "c_wx6zb55";
#   ci = 80;
# val = {"subnavId":4};    window.system = {};
#
#   window.openPlatform = '';
#   window.openPlatformSub = '';
#   window.$mtsiFlag = '0';
#   window.NODE_ENV = 'production';
#
#   </script>
# <link href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/common.6b1d782c.css" rel="stylesheet"/>
# <link href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/board-index.92a06072.css" rel="stylesheet"/>
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/stat.88d57c80.js"></script><script async="" charset="utf-8" defer="" src="//analytics.meituan.com/source/stable/web.js"></script>
# <script>if(window.devicePixelRatio >= 2) { document.write('<link rel="stylesheet" href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image-2x.8ba7074d.css"/>') }</script>
# <style>
#     @font-face {
#       font-family: stonefont;
#       src: url('//vfile.meituan.net/colorstone/745beabbd0975d832ba41e37de40ad063428.eot');
#       src: url('//vfile.meituan.net/colorstone/745beabbd0975d832ba41e37de40ad063428.eot?#iefix') format('embedded-opentype'),
#            url('//vfile.meituan.net/colorstone/f290f8d42f3365be7a68a9f5f46dd5fa2272.woff') format('woff');
#     }
#
#     .stonefont {
#       font-family: stonefont;
#     }
#   </style>
# <script>
#   var _hmt = _hmt || [];
#   (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?703e94591e87be68cc8da0da7cbd0be2";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
#   })();
#   </script>
# <meta content="off" from="v3api" name="lx:autopv"/><meta content="movie" from="v3api" name="lx:appnm"/><meta content="movie" from="v3api" name="lx:category"/></head>
# <body>
# <div class="header">
# <div class="header-inner">
# <a class="logo" data-act="icon-click" href="//maoyan.com">猫眼电影</a>
# <div class="city-container" data-val="{currentcityid:80 }">
# <div class="city-selected">
# <div class="city-name">
#                   苏州
#                   <span class="caret"></span>
# </div>
# </div>
# <div class="city-list" data-val="{ localcityid: 80 }">
# <div class="city-list-header">定位城市：<a class="js-geo-city" data-ci="80">苏州</a></div>
# </div>
# </div>
# <div class="nav">
# <ul class="navbar">
# <li><a data-act="home-click" href="/">首页</a></li>
# <li><a data-act="movies-click" href="/films">电影</a></li>
# <li><a data-act="cinemas-click" href="/cinemas">影院</a></li>
# <li><a href="http://www.gewara.com">演出</a></li>
# <li><a class="active" data-act="board-click" href="/board">榜单</a></li>
# <li><a data-act="hotNews-click" href="/news">热点</a></li>
# <li><a href="/edimall">商城</a></li>
# </ul>
# </div>
# <div class="user-info">
# <div class="user-avatar J-login">
# <img src="https://p0.meituan.net/movie/7dd82a16316ab32c8359debdb04396ef2897.png"/>
# <span class="caret"></span>
# <ul class="user-menu no-login-menu">
# <li><a href="javascript:void 0">登录</a></li>
# </ul>
# </div>
# </div>
# <form action="/query" class="search-form" data-actform="search-click" target="_blank">
# <input autocomplete="off" class="search" maxlength="32" name="kw" placeholder="找影视剧、影人、影院" type="search"/>
# <input class="submit" type="submit" value=""/>
# </form>
# <div class="app-download">
# <a href="/app" target="_blank">
# <span class="iphone-icon"></span>
# <span class="apptext">APP下载</span>
# <span class="caret"></span>
# <div class="download-icon">
# <p class="down-title">扫码下载APP</p>
# <p class="down-content">选座更优惠</p>
# </div>
# </a>
# </div>
# </div>
# </div>
# <div class="header-placeholder"></div>
# <div class="subnav">
# <ul class="navbar">
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:7}" href="/board/7">热映口碑榜</a>
# </li>
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:6}" href="/board/6">最受期待榜</a>
# </li>
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:1}" href="/board/1">国内票房榜</a>
# </li>
# <li>
# <a data-act="subnav-click" data-val="{subnavClick:2}" href="/board/2">北美票房榜</a>
# </li>
# <li>
# ...
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1379}" href="/films/1379" title="真爱至上">真爱至上</a></p>
# <p class="star">
#                 主演：休·格兰特,比尔·奈伊,连姆·尼森
#         </p>
# <p class="releasetime">上映时间：2003-11-21(英国)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">6</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-93">93</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:672130}" href="/films/672130" title="奇迹男孩">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="奇迹男孩" class="board-img" data-src="https://p0.meituan.net/movie/e5e49dad53d8cfba7316d486e799345c395906.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:672130}" href="/films/672130" title="奇迹男孩">奇迹男孩</a></p>
# <p class="star">
#                 主演：雅各布·特瑞布雷,朱莉娅·罗伯茨,欧文·威尔逊
#         </p>
# <p class="releasetime">上映时间：2018-01-19</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">2</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-94">94</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1202}" href="/films/1202" title="大鱼">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="大鱼" class="board-img" data-src="https://p0.meituan.net/movie/0b1474181d53a328c2e87d018fa088b9241815.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1202}" href="/films/1202" title="大鱼">大鱼</a></p>
# <p class="star">
#                 主演：伊万·麦克格雷格,阿尔伯特·芬尼,杰西卡·兰格
#         </p>
# <p class="releasetime">上映时间：2003-12-04(美国)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">6</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-95">95</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:4883}" href="/films/4883" title="钢琴家">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="钢琴家" class="board-img" data-src="https://p0.meituan.net/movie/389d81144eab106ac08c870bb4e366be547402.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:4883}" href="/films/4883" title="钢琴家">钢琴家</a></p>
# <p class="star">
#                 主演：艾德里安·布洛迪,艾米莉娅·福克斯,米哈乌·热布罗夫斯基
#         </p>
# <p class="releasetime">上映时间：2002-05-24(法国)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">9</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-96">96</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1233}" href="/films/1233" title="饮食男女">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="饮食男女" class="board-img" data-src="https://p1.meituan.net/movie/8d54378f5aa5891b27da166063fe5efe793583.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1233}" href="/films/1233" title="饮食男女">饮食男女</a></p>
# <p class="star">
#                 主演：郎雄,吴倩莲,杨贵媚
#         </p>
# <p class="releasetime">上映时间：1994-08-03(美国)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">8</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-97">97</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:1219776}" href="/films/1219776" title="网络谜踪">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="网络谜踪" class="board-img" data-src="https://p0.meituan.net/movie/36db8e805a15cc0475ebe3f0c9b56c9e782659.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:1219776}" href="/films/1219776" title="网络谜踪">网络谜踪</a></p>
# <p class="star">
#                 主演：约翰·赵,米切尔·拉,黛博拉·梅辛
#         </p>
# <p class="releasetime">上映时间：2018-12-14</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">6</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-98">98</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:20131}" href="/films/20131" title="致命魔术">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="致命魔术" class="board-img" data-src="https://p1.meituan.net/movie/ef83b1e2ef6fa1e6f736521a356b829a334336.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:20131}" href="/films/20131" title="致命魔术">致命魔术</a></p>
# <p class="star">
#                 主演：休·杰克曼,克里斯蒂安·贝尔,迈克尔·凯恩
#         </p>
# <p class="releasetime">上映时间：2006-10-17(意大利)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">8</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-99">99</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:78646}" href="/films/78646" title="模仿游戏">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="模仿游戏" class="board-img" data-src="https://p0.meituan.net/moviemachine/8265143afdbafba9d3ad7993bc3472e4508519.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:78646}" href="/films/78646" title="模仿游戏">模仿游戏</a></p>
# <p class="star">
#                 主演：本尼迪克特·康伯巴奇,凯拉·奈特莉,马修·古迪
#         </p>
# <p class="releasetime">上映时间：2015-07-21</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">3</i></p>
# </div>
# </div>
# </div>
# </dd>
# <dd>
# <i class="board-index board-index-100">100</i>
# <a class="image-link" data-act="boarditem-click" data-val="{movieId:907}" href="/films/907" title="禁闭岛">
# <img alt="" class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png"/>
# <img alt="禁闭岛" class="board-img" data-src="https://p0.meituan.net/movie/985156d0619734f9eacb45d15e2ba3231323113.jpg@160w_220h_1e_1c"/>
# </a>
# <div class="board-item-main">
# <div class="board-item-content">
# <div class="movie-item-info">
# <p class="name"><a data-act="boarditem-click" data-val="{movieId:907}" href="/films/907" title="禁闭岛">禁闭岛</a></p>
# <p class="star">
#                 主演：莱昂纳多·迪卡普里奥,马克·鲁法洛,本·金斯利
#         </p>
# <p class="releasetime">上映时间：2010-02-13(德国)</p> </div>
# <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">7</i></p>
# </div>
# </div>
# </div>
# </dd>
# </dl>
# </div>
# <div class="pager-main">
# <ul class="list-pager">
# <li> <a class="page_9" href="?offset=80">上一页</a>
# </li>
# <li>
# <a class="page_1" href="?offset=0">1</a>
# </li>
# <li class="sep">...</li>
# <li>
# <a class="page_6" href="?offset=50">6</a>
# </li>
# <li>
# <a class="page_7" href="?offset=60">7</a>
# </li>
# <li>
# <a class="page_8" href="?offset=70">8</a>
# </li>
# <li>
# <a class="page_9" href="?offset=80">9</a>
# </li>
# <li class="active">
# <a class="page_10" href="javascript:void(0);" style="cursor: default">10</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footer" style="visibility: visible;">
# <p class="friendly-links">
#     关于猫眼 :
#     <a href="http://ir.maoyan.com/s/index.php#pageScroll0" target="_blank">关于我们</a>
# <span></span>
# <a href="http://ir.maoyan.com/s/index.php#pageScroll1" target="_blank">管理团队</a>
# <span></span>
# <a href="http://ir.maoyan.com/s/index.php#pageScroll2" target="_blank">投资者关系</a>
#
#     友情链接 :
#     <a data-query="utm_source=wwwmaoyan" href="http://www.meituan.com" target="_blank">美团网</a>
# <span></span>
# <a data-query="utm_source=wwwmaoyan" href="http://www.gewara.com">格瓦拉</a>
# <span></span>
# <a data-query="utm_source=wwwmaoyan" href="http://i.meituan.com/client" target="_blank">美团下载</a>
# <span></span>
# <a data-query="utm_source=maoyan_pc" href="https://www.huanxi.com" target="_blank">欢喜首映</a>
# </p>
# <p class="friendly-links">
#     商务合作邮箱：v@maoyan.com
#     客服电话：10105335
#     违法和不良信息/涉未成年人有害信息举报电话：4006018900
#   </p>
# <p class="friendly-links">
#     用户举报/涉未成年人有害信息举报邮箱：tousujubao@meituan.com
#     舞弊线索举报邮箱：wubijubao@maoyan.com
#   </p>
# <p class="friendly-links credentials">
# <a href="/about/licence/1" target="_blank">中华人民共和国增值电信业务经营许可证 京B2-20190350</a>
# <span></span>
# <a href="/about/licence/4" target="_blank">营业性演出许可证 京演（机构）（2019）4094号</a>
# </p>
# <p class="friendly-links credentials">
# <a href="/about/licence/3" target="_blank">广播电视节目制作经营许可证 （京）字第08478号</a>
# <span></span>
# <a href="/about/licence/2" target="_blank">网络文化经营许可证 京网文（2019）3837-369号 </a>
# </p>
# <p class="friendly-links credentials">
# <a href="/rules/agreement" target="_blank">猫眼用户服务协议 </a>
# <span></span>
# <a href="/rules/rule" target="_blank">猫眼平台交易规则总则 </a>
# <span></span>
# <a href="/rules/privacy" target="_blank">隐私政策 </a>
# </p>
# <p class="friendly-links credentials">
# <a href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=11010102003232" target="_blank">京公网安备
#       11010102003232号</a>
# <span></span>
# <a href="http://beian.miit.gov.cn/" target="_blank">京ICP备16022489号-1</a>
# </p>
# <p>北京猫眼文化传媒有限公司</p>
# <p>
#     ©<span class="my-footer-year">2021</span>
#     猫眼电影 maoyan.com</p>
# <div class="certificate">
# <a href="http://sq.ccm.gov.cn:80/ccnt/sczr/service/business/emark/toDetail/350CF8BCA8416C4FE0530140A8C0957E" target="_blank">
# <img src="https://p0.meituan.net/moviemachine/e54374ccf134d1f7b2c5b075a74fca525326.png"/>
# </a>
# <a href="/about/licence/5" target="_blank">
# <img src="https://p1.meituan.net/moviemachine/805f605d5cf1b1a02a4e3a5e29df003b8376.png"/>
# </a>
# <a href="https://www.12377.cn" target="_blank">
# <img src="https://p0.meituan.net/scarlett/3cd2a9b7dc179531d20d27a5fd686e783787.png"/>
# </a>
# </div>
# </div>
# <script crossorigin="anonymous" src="//www.dpfile.com/app/owl/static/owl_1.7.11.js"></script>
# <script>
#       Owl.start({
#         project: 'com.sankuai.movie.fe.mywww',
#         pageUrl: location.href.split('?')[0].replace(/\/\d+/g, '/:id'),
#         devMode: false
#       })
#     </script>
# <!--[if IE 8]><script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/es5-shim.bbad933f.js"></script><![endif]-->
# <!--[if IE 8]><script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/es5-sham.d6ea26f4.js"></script><![endif]-->
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/common.c5e8f9fe.js"></script>
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/board-index.be8ae70e.js"></script>
# </body></html>
# [('1', '/films/1200486', '我不是药神', '徐峥,周一围,王传君\n        ', '2018-07-05', '9.', '6'), ('2', '/films/1297', '肖申克的救赎', '蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿\n        ', '1994-09-10', '9.', '5'), ('3', '/films/1206605', '绿皮书', '维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼\n        ', '2019-03-01', '9.', '5'), ('4', '/films/1292', '海上钢琴师', '蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世\n        ', '2019-11-15', '9.', '3'), ('5', '/films/1211270', '哪吒之魔童降世', '吕艳婷,囧森瑟夫,瀚墨\n        ', '2019-07-26', '9.', '6'), ('6', '/films/1203', '霸王别姬', '张国荣,张丰毅,巩俐\n        ', '1993-07-26', '9.', '4'), ('7', '/films/1216365', '小偷家族', '中川雅也,安藤樱,松冈茉优\n        ', '2018-08-03', '8.', '1'), ('8', '/films/1303', '美丽人生', '罗伯托·贝尼尼,朱斯蒂诺·杜拉诺,赛尔乔·比尼·布斯特里克\n        ', '2020-01-03', '9.', '3'), ('9', '/films/4055', '这个杀手不太冷', '让·雷诺,加里·奥德曼,娜塔莉·波特曼\n        ', '1994-09-14', '9.', '4'), ('10', '/films/416', '盗梦空间', '莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特\n        ', '2010-09-01', '9.', '0'), ('11', '/films/1633', '阿甘正传', '汤姆·汉克斯,罗宾·怀特,加里·西尼斯\n        ', '1994-07-06', '9.', '4'), ('12', '/films/1212', '千与千寻', '柊瑠美,周冬雨,入野自由\n        ', '2019-06-21', '9.', '3'), ('13', '/films/78341', '星际穿越', '马修·麦康纳,安妮·海瑟薇,杰西卡·查斯坦\n        ', '2014-11-12', '9.', '3'), ('14', '/films/1304', '楚门的世界', '金·凯瑞,劳拉·琳妮,诺亚·艾默里奇\n        ', '1998', '8.', '9'), ('15', '/films/70976', '触不可及', '弗朗索瓦·克鲁塞,奥玛·希,安娜·勒尼\n        ', '2011-11-02', '9.', '1'), ('16', '/films/3667', '辛德勒的名单', '连姆·尼森,拉尔夫·费因斯,本·金斯利\n        ', '1993-11-30', '9.', '2'), ('17', '/films/1319', '情书', '中山美穗,丰川悦司,酒井美纪\n        ', '1999-03-01', '8.', '9'), ('18', '/films/342068', '寻梦环游记', '安东尼·冈萨雷斯,本杰明·布拉特,盖尔·加西亚·贝纳尔\n        ', '2017-11-24', '9.', '6'), ('19', '/films/588362', '摔跤吧！爸爸', '阿米尔·汗,沙克希·坦沃,法缇玛·萨那·纱卡\n        ', '2017-05-05', '9.', '8'), ('20', '/films/1218727', '何以为家', '赞恩·阿尔·拉菲亚,约丹诺斯·希费罗,博鲁瓦蒂夫·特雷杰·班科尔\n        ', '2019-04-29', '9.', '3'), ('21', '/films/995', '少年派的奇幻漂流', '苏拉·沙玛,伊尔凡·可汗,塔布\n        ', '2012-11-22', '9.', '0'), ('22', '/films/1215201', '小丑', '华金·菲尼克斯,罗伯特·德尼罗,亚历克·鲍德温\n        ', '2019-10-04', '8.', '6'), ('23', '/films/38286', '忠犬八公的故事', 'Forest,理查·基尔,琼·艾伦\n        ', '2009-06-13', '9.', '3'), ('24', '/films/46818', '怦然心动', '玛德琳·卡罗尔,卡兰·麦克奥利菲,艾丹•奎因\n        ', '2010-07-26', '8.', '9'), ('25', '/films/267', '泰坦尼克号', '莱昂纳多·迪卡普里奥,凯特·温丝莱特,比利·赞恩\n        ', '1998-04-03', '9.', '4'), ('26', '/films/344881', '你的名字。', '上白石萌音,佟心竹,神木隆之介\n        ', '2016-12-02', '9.', '2'), ('27', '/films/899', '当幸福来敲门', '威尔·史密斯,贾登·史密斯,坦迪·牛顿\n        ', '2008-01-17', '9.', '3'), ('28', '/films/43', '三傻大闹宝莱坞', '阿米尔·汗,黄渤,卡琳娜·卡普\n        ', '2011-12-08', '9.', '1'), ('29', '/films/718', '天堂电影院', '菲利浦·诺瓦雷,雅克·贝汉,马克·莱昂纳蒂\n        ', '2021-06-11', '9.', '3'), ('30', '/films/67214', '熔炉', '孔刘,郑有美,金智英\n        ', '2011-09-22', '8.', '8'), ('31', '/films/1205', '放牛班的春天', '热拉尔·朱尼奥,让-巴蒂斯特·莫尼耶,玛丽·布奈尔\n        ', '2004-10-16', '8.', '8'), ('32', '/films/123', '龙猫', '秦岚,糸井重里,岛本须美\n        ', '2018-12-14', '9.', '2'), ('33', '/films/458721', '看不见的客人', '马里奥·卡萨斯,阿娜·瓦格纳,何塞·科罗纳多\n        ', '2017-09-15', '9.', '4'), ('34', '/films/1247', '教父', '马龙·白兰度,阿尔·帕西诺,詹姆斯·肯恩\n        ', '2015-04-18', '9.', '3'), ('35', '/films/341178', '头号玩家', '泰伊·谢里丹,奥利维亚·库克,本·门德尔森\n        ', '2018-03-30', '9.', '0'), ('36', '/films/20394', '被嫌弃的松子的一生', '中谷美纪,永山瑛太,伊势谷友介\n        ', '2006-05-27', '8.', '5'), ('37', '/films/1375', '活着', '葛优,巩俐,牛犇\n        ', '1994-05-17', '9.', '0'), ('38', '/films/342754', '三块广告牌', '弗兰西斯·麦克多蒙德,伍迪·哈里森,山姆·洛克威尔\n        ', '2018-03-02', '8.', '6'), ('39', '/films/409801', '请以你的名字呼唤我', '提莫西·查拉梅,艾米·汉莫,迈克尔·斯图巴\n        ', '2017-01-22', '8.', '0'), ('40', '/films/1204', '死亡诗社', '罗宾·威廉姆斯,伊桑·霍克,柯特伍德·史密斯\n        ', '1989-06-02', '8.', '7'), ('41', '/films/6289', '闻香识女人', '阿尔·帕西诺,克里斯·奥唐纳,加布里埃尔·安瓦尔\n        ', '1992-12-23', '8.', '8'), ('42', '/films/246286', '疯狂动物城', '金妮弗·古德温,杰森·贝特曼,伊德瑞斯·艾尔巴\n        ', '2016-03-04', '9.', '5'), ('43', '/films/488', '机器人总动员', '本·贝尔特,艾丽莎·奈特,杰夫·格尔林\n        ', '2008-06-27', '9.', '3'), ('44', '/films/248172', '复仇者联盟4：终局之战', '小罗伯特·唐尼,克里斯·埃文斯,马克·鲁法洛\n        ', '2019-04-24', '9.', '1'), ('45', '/fil ...

# %%
len(moives)
# Out:
# 100

# %%
data_list = []
for i in moives:
    sin_list = []
    for j in range(len(i)-1):
        if j == 3:
            sin_list.append(i[j].replace("\n","").strip())
        elif j == 5:
            sin_list.append(i[j]+i[j+1])
        else:
            sin_list.append(i[j])
    data_list.append(sin_list)
print(data_list)
# Out:
# [['1', '/films/1200486', '我不是药神', '徐峥,周一围,王传君', '2018-07-05', '9.6'], ['2', '/films/1297', '肖申克的救赎', '蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿', '1994-09-10', '9.5'], ['3', '/films/1206605', '绿皮书', '维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼', '2019-03-01', '9.5'], ['4', '/films/1292', '海上钢琴师', '蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世', '2019-11-15', '9.3'], ['5', '/films/1211270', '哪吒之魔童降世', '吕艳婷,囧森瑟夫,瀚墨', '2019-07-26', '9.6'], ['6', '/films/1203', '霸王别姬', '张国荣,张丰毅,巩俐', '1993-07-26', '9.4'], ['7', '/films/1216365', '小偷家族', '中川雅也,安藤樱,松冈茉优', '2018-08-03', '8.1'], ['8', '/films/1303', '美丽人生', '罗伯托·贝尼尼,朱斯蒂诺·杜拉诺,赛尔乔·比尼·布斯特里克', '2020-01-03', '9.3'], ['9', '/films/4055', '这个杀手不太冷', '让·雷诺,加里·奥德曼,娜塔莉·波特曼', '1994-09-14', '9.4'], ['10', '/films/416', '盗梦空间', '莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特', '2010-09-01', '9.0'], ['11', '/films/1633', '阿甘正传', '汤姆·汉克斯,罗宾·怀特,加里·西尼斯', '1994-07-06', '9.4'], ['12', '/films/1212', '千与千寻', '柊瑠美,周冬雨,入野自由', '2019-06-21', '9.3'], ['13', '/films/78341', '星际穿越', '马修·麦康纳,安妮·海瑟薇,杰西卡·查斯坦', '2014-11-12', '9.3'], ['14', '/films/1304', '楚门的世界', '金·凯瑞,劳拉·琳妮,诺亚·艾默里奇', '1998', '8.9'], ['15', '/films/70976', '触不可及', '弗朗索瓦·克鲁塞,奥玛·希,安娜·勒尼', '2011-11-02', '9.1'], ['16', '/films/3667', '辛德勒的名单', '连姆·尼森,拉尔夫·费因斯,本·金斯利', '1993-11-30', '9.2'], ['17', '/films/1319', '情书', '中山美穗,丰川悦司,酒井美纪', '1999-03-01', '8.9'], ['18', '/films/342068', '寻梦环游记', '安东尼·冈萨雷斯,本杰明·布拉特,盖尔·加西亚·贝纳尔', '2017-11-24', '9.6'], ['19', '/films/588362', '摔跤吧！爸爸', '阿米尔·汗,沙克希·坦沃,法缇玛·萨那·纱卡', '2017-05-05', '9.8'], ['20', '/films/1218727', '何以为家', '赞恩·阿尔·拉菲亚,约丹诺斯·希费罗,博鲁瓦蒂夫·特雷杰·班科尔', '2019-04-29', '9.3'], ['21', '/films/995', '少年派的奇幻漂流', '苏拉·沙玛,伊尔凡·可汗,塔布', '2012-11-22', '9.0'], ['22', '/films/1215201', '小丑', '华金·菲尼克斯,罗伯特·德尼罗,亚历克·鲍德温', '2019-10-04', '8.6'], ['23', '/films/38286', '忠犬八公的故事', 'Forest,理查·基尔,琼·艾伦', '2009-06-13', '9.3'], ['24', '/films/46818', '怦然心动', '玛德琳·卡罗尔,卡兰·麦克奥利菲,艾丹•奎因', '2010-07-26', '8.9'], ['25', '/films/267', '泰坦尼克号', '莱昂纳多·迪卡普里奥,凯特·温丝莱特,比利·赞恩', '1998-04-03', '9.4'], ['26', '/films/344881', '你的名字。', '上白石萌音,佟心竹,神木隆之介', '2016-12-02', '9.2'], ['27', '/films/899', '当幸福来敲门', '威尔·史密斯,贾登·史密斯,坦迪·牛顿', '2008-01-17', '9.3'], ['28', '/films/43', '三傻大闹宝莱坞', '阿米尔·汗,黄渤,卡琳娜·卡普', '2011-12-08', '9.1'], ['29', '/films/718', '天堂电影院', '菲利浦·诺瓦雷,雅克·贝汉,马克·莱昂纳蒂', '2021-06-11', '9.3'], ['30', '/films/67214', '熔炉', '孔刘,郑有美,金智英', '2011-09-22', '8.8'], ['31', '/films/1205', '放牛班的春天', '热拉尔·朱尼奥,让-巴蒂斯特·莫尼耶,玛丽·布奈尔', '2004-10-16', '8.8'], ['32', '/films/123', '龙猫', '秦岚,糸井重里,岛本须美', '2018-12-14', '9.2'], ['33', '/films/458721', '看不见的客人', '马里奥·卡萨斯,阿娜·瓦格纳,何塞·科罗纳多', '2017-09-15', '9.4'], ['34', '/films/1247', '教父', '马龙·白兰度,阿尔·帕西诺,詹姆斯·肯恩', '2015-04-18', '9.3'], ['35', '/films/341178', '头号玩家', '泰伊·谢里丹,奥利维亚·库克,本·门德尔森', '2018-03-30', '9.0'], ['36', '/films/20394', '被嫌弃的松子的一生', '中谷美纪,永山瑛太,伊势谷友介', '2006-05-27', '8.5'], ['37', '/films/1375', '活着', '葛优,巩俐,牛犇', '1994-05-17', '9.0'], ['38', '/films/342754', '三块广告牌', '弗兰西斯·麦克多蒙德,伍迪·哈里森,山姆·洛克威尔', '2018-03-02', '8.6'], ['39', '/films/409801', '请以你的名字呼唤我', '提莫西·查拉梅,艾米·汉莫,迈克尔·斯图巴', '2017-01-22', '8.0'], ['40', '/films/1204', '死亡诗社', '罗宾·威廉姆斯,伊桑·霍克,柯特伍德·史密斯', '1989-06-02', '8.7'], ['41', '/films/6289', '闻香识女人', '阿尔·帕西诺,克里斯·奥唐纳,加布里埃尔·安瓦尔', '1992-12-23', '8.8'], ['42', '/films/246286', '疯狂动物城', '金妮弗·古德温,杰森·贝特曼,伊德瑞斯·艾尔巴', '2016-03-04', '9.5'], ['43', '/films/488', '机器人总动员', '本·贝尔特,艾丽莎·奈特,杰夫·格尔林', '2008-06-27', '9.3'], ['44', '/films/248172', '复仇者联盟4：终局之战', '小罗伯特·唐尼,克里斯·埃文斯,马克·鲁法洛', '2019-04-24', '9.1'], ['45', '/films/2039', '末代皇帝', '尊龙,陈冲,彼得·奥图尔', '1987-10-04', '8.8'], ['46', '/films/1284164', '西西里的美丽传说', '莫妮卡·安娜·玛丽亚·贝鲁奇,朱塞佩·苏尔法罗,玛蒂尔德·皮亚纳', '2000-10-26', '8.2'], ['47', '/films/553231', '心灵奇旅', '杰米·福克斯,蒂娜·菲,菲利西亚·拉斯海德', '2020-12-25', '9.2'], ['48', '/films/182', '让子弹飞', '姜文,周润发,葛优', '2010-12-16', '8.5'], ['49', '/films/18318', '本杰明·巴顿奇事', '布拉德·皮特,凯特·布兰切特,塔拉吉·P·汉森', '2008-12-25', '8.8'], ['50', '/films/1291', '搏击俱乐部', '爱德华·哈里森·诺顿,布拉德·皮特,海伦娜·伯翰·卡特', '1999-09-10', '8.8'], ['51', '/films/243', '阿凡达', '萨姆·沃辛顿,佐伊·索尔达娜,米歇尔·罗德里格兹', '2010-01-04', '9.4'], ['52', '/films/1332', '美国往事', '罗伯特·德尼罗,詹姆斯·伍兹,伊丽莎白·麦戈文', '2015-04-23', '9.1' ...

# %%
def scrapSubWeb(link):
    url = 'https://maoyan.com' + link[1]
    result = scrapWeb(url)
    
    match = result.find_all(class_="ellipsis")
    findType = re.compile('> (.*) <')
    MovieType = re.findall(findType, str(match[1]))
    print(MovieType)
    strType = ''
    for i in MovieType:
        strType += i + '，'
    link.append(strType[:-1])
    
    findDuration = re.compile('(...分钟)')
    duration = re.findall(findDuration, str(match[2]))
    print(duration)
    link.append(duration[0])
    
    findRegion = re.compile('([\u4e00-\u9fa5]{0,20})\n.*\/')
    region = re.findall(findRegion, str(match[2]))
    print(region[0])
    link.append(region[0])

    matchDirector = result.find_all(class_="celebrity-group")[0]
    matchDirector = matchDirector.find_all(class_="name")
    findDirector = re.compile('<a.*?>(.*?)</a>', re.S)
    director = re.findall(findDirector, str(matchDirector))
    print(director)
    strDirector = ''
    for i in director:
        strDirector += i.replace("\n","").strip() + '，'
    link.append(strDirector[:-1])
    
    findIncome = re.compile('>(.*)<')
    try:
        matchDirector = str(result.find_all(class_="mbox-name")[2])
        income = str(re.findall(findIncome, matchDirector)[0])
        if income != '暂无':
            income += '万'
    except:
        income = '暂无'    
    print(income)
    link.append(income)
    
    time.sleep(2)

# %%
sub_list_1 = data_list[:20].copy()
for link in sub_list_1:
    scrapSubWeb(link)
# Out:
# ['剧情', '喜剧']
# ['117分钟']
# 中国大陆
# ['\n      文牧野\n    ']
# 310002万
# ['剧情', '犯罪']
# ['142分钟']
# 美国
# ['\n      弗兰克·德拉邦特\n    ']
# 暂无
# ['剧情', '喜剧', '传记']
# ['130分钟']
# 美国
# ['\n      彼得·法雷里\n    ']
# 47872万
# ['剧情', '爱情', '音乐']
# ['126分钟']
# 意大利
# ['\n      朱塞佩·托纳多雷\n    ']
# 14376万
# ['动画', '喜剧', '奇幻']
# ['110分钟']
# 中国大陆
# ['\n      饺子\n    ']
# 66507万
# ['剧情', '爱情']
# ['171分钟']
# 中国香港
# ['\n      陈凯歌\n    ']
# 5万
# ['剧情', '犯罪']
# ['121分钟']
# 日本
# ['\n      是枝裕和\n    ']
# 9675万
# ['战争', '剧情', '爱情']
# ['116分钟']
# 意大利
# ['\n      罗伯托·贝尼尼\n    ']
# 5979万
# ['剧情', '动作', '犯罪']
# ['110分钟']
# 法国
# ['\n      吕克·贝松\n    ']
# 暂无
# ['动作', '悬疑', '惊悚', '科幻']
# ['148分钟']
# 英国
# ['\n      克里斯托弗·诺兰\n    ']
# 49620万
# ['剧情', '爱情']
# ['142分钟']
# 美国
# ['\n      罗伯特·泽米吉斯\n    ']
# 暂无
# ['动画', '冒险', '奇幻', '家庭']
# ['125分钟']
# 日本
# ['\n      宫崎骏\n    ']
# 48828万
# ['剧情', '科幻', '冒险']
# ['169分钟']
# 美国
# ['\n      克里斯托弗·诺兰\n    ']
# 87697万
# ['剧情']
# ['103分钟']
# 美国
# ['\n      彼得·威尔\n    ']
# 暂无
# ['剧情', '喜剧']
# ['112分钟']
# 法国
# ['\n      奥利维埃·纳卡什\n    ', '\n      埃里克·托莱达诺\n    ']
# 暂无
# ['剧情', '历史', '战争']
# ['195分钟']
# 美国
# ['\n      史蒂文·斯皮尔伯格\n    ']
# 暂无
# ['剧情', '爱情']
# ['116分钟']
# 日本
# ['\n      岩井俊二\n    ']
# 暂无
# ['动画', '冒险', '家庭']
# ['105分钟']
# 美国
# ['\n      李·昂克里奇\n    ', '\n      阿德里安·莫利纳\n    ']
# 123008万
# ['喜剧', '动作', '家庭']
# ['140分钟']
# 印度
# ['\n      涅提·蒂瓦里\n    ']
# 129932万
# ['剧情']
# ['116分钟']
# 黎巴嫩
# ['\n      娜丁·拉巴基\n    ']
# 37684万

# %%
sub_list_2 = data_list[20:40].copy()
for link in sub_list_2:
    scrapSubWeb(link)
# Out:
# ['剧情', '奇幻', '冒险']
# ['127分钟']
# 加拿大
# ['\n      李安\n    ']
# 57288万
# ['剧情', '惊悚', '犯罪']
# ['122分钟']
# 美国
# ['\n      托德·菲利普斯\n    ']
# 暂无
# ['剧情']
# [' 93分钟']
# 英国
# ['\n      拉斯·霍尔斯道姆\n    ']
# 暂无
# ['爱情']
# [' 90分钟']
# 美国
# ['\n      罗伯·莱纳\n    ']
# 暂无
# ['剧情', '爱情', '灾难']
# ['194分钟']
# 美国
# ['\n      詹姆斯·卡梅隆\n    ']
# 130615万
# ['爱情', '动画', '奇幻']
# ['106分钟']
# 日本
# ['\n      新海诚\n    ']
# 57571万
# ['剧情', '家庭', '传记']
# ['117分钟']
# 美国
# ['\n      加布里埃莱·穆奇诺\n    ']
# 981万
# ['剧情', '喜剧', '冒险']
# ['171分钟']
# 印度
# ['\n      拉吉库马尔·希拉尼\n    ']
# 1396万
# ['剧情', '爱情']
# ['124分钟']
# 意大利
# ['\n      朱塞佩·托纳多雷\n    ']
# 2000万
# ['剧情']
# ['125分钟']
# 韩国
# ['\n      黄东赫\n    ']
# 暂无
# ['剧情', '喜剧', '音乐']
# [' 96分钟']
# 瑞士
# ['\n      克里斯托夫·巴拉蒂\n    ']
# 暂无
# ['动画', '冒险', '奇幻', '家庭']
# [' 86分钟']
# 日本
# ['\n      宫崎骏\n    ']
# 17370万
# ['犯罪', '悬疑', '惊悚']
# ['106分钟']
# 西班牙
# ['\n      奥里奥尔·保罗\n    ']
# 17258万
# ['剧情', '惊悚', '犯罪']
# ['175分钟']
# 美国
# ['\n      弗朗西斯·福特·科波拉\n    ']
# 暂无
# ['动作', '冒险', '科幻']
# ['140分钟']
# 美国
# ['\n      史蒂文·斯皮尔伯格\n    ']
# 139668万
# ['剧情', '歌舞']
# ['130分钟']
# 日本
# ['\n      中岛哲也\n    ', '\n      酒井圣博\n    ']
# 暂无
# ['剧情', '家庭', '历史']
# ['132分钟']
# 中国香港
# ['\n      张艺谋\n    ']
# 暂无
# ['剧情', '犯罪']
# ['115分钟']
# 美国
# ['\n      马丁·麦克唐纳\n    ']
# 6499万
# ['爱情', '剧情']
# ['132分钟']
# 德国
# ['\n      卢卡·瓜达尼诺\n    ']
# 暂无
# ['剧情']
# ['128分钟']
# 美国
# ['\n      彼得·威尔\n    ']
# 暂无

# %%
sub_list_3 = data_list[40:60].copy()
for link in sub_list_3:
    scrapSubWeb(link)
# Out:
# ['剧情']
# ['157分钟']
# 美国
# ['\n      马丁·布莱斯特\n    ']
# 暂无
# ['动画', '动作', '冒险']
# ['109分钟']
# 美国
# ['\n      拜伦·霍华德\n    ', '\n      瑞奇·摩尔\n    ']
# 153190万
# ['喜剧', '科幻', '动画']
# [' 98分钟']
# 美国
# ['\n      安德鲁·斯坦顿\n    ']
# 暂无
# ['动作', '冒险', '奇幻']
# ['181分钟']
# 美国
# ['\n      乔·罗素\n    ', '\n      安东尼·罗素\n    ']
# 425013万
# ['剧情']
# ['163分钟']
# 美国
# ['\n      贝纳尔多·贝托鲁奇\n    ']
# 暂无
# ['剧情', '爱情', '战争']
# ['109分钟']
# 意大利
# ['\n      朱塞佩·托纳多雷\n    ']
# 暂无
# ['动画', '喜剧', '冒险']
# ['101分钟']
# 美国
# ['\n      彼特·道格特\n    ', '\n      坎普·鲍尔斯\n    ']
# 37618万
# ['剧情', '喜剧', '动作', '西部']
# ['132分钟']
# 中国香港
# ['\n      姜文\n    ']
# 63675万
# ['剧情', '爱情', '奇幻']
# ['166分钟']
# 美国
# ['\n      大卫·芬奇\n    ']
# 暂无
# ['剧情', '动作', '悬疑', '惊悚']
# ['139分钟']
# 德国
# ['\n      大卫·芬奇\n    ']
# 暂无
# ['动作', '科幻', '冒险']
# ['162分钟']
# 英国
# ['\n      詹姆斯·卡梅隆\n    ']
# 暂无
# ['剧情', '犯罪']
# ['229分钟']
# 美国
# ['\n      赛尔乔·莱翁内\n    ']
# 暂无
# ['剧情', '悬疑']
# ['137分钟']
# 德国
# ['\n      弗洛里安·亨克尔·冯·多纳斯马尔克\n    ']
# 暂无
# ['剧情', '喜剧', '动画', '冒险']
# [' 96分钟']
# 美国
# ['\n      彼特·道格特\n    ', '\n      鲍勃·彼德森\n    ']
# 7906万
# ['爱情']
# ['122分钟']
# 德国
# ['\n      让-皮埃尔·热内\n    ']
# 暂无
# ['剧情', '爱情', '历史', '战争']
# ['238分钟']
# 美国
# ['\n      乔治·库克\n    ', '\n      维克多·弗莱明\n    ']
# 暂无
# ['剧情']
# ['133分钟']
# 美国
# ['\n      米洛斯·福尔曼\n    ']
# 暂无
# ['剧情', '爱情', '家庭']
# ['173分钟']
# 日本
# ['\n      杨德昌\n    ']
# 暂无
# ['剧情', '传记']
# ['135分钟']
# 美国
# ['\n      朗·霍华德\n    ']
# 暂无
# ['剧情', '悬疑', '惊悚', '犯罪']
# ['149分钟']
# 美国
# ['\n      大卫·芬奇\n    ']
# 暂无

# %%
sub_list_4 = data_list[60:80].copy()
for link in sub_list_4:
    scrapSubWeb(link)
# Out:
# ['剧情', '喜剧', '冒险']
# ['100分钟']
# 英国
# ['\n      韦斯·安德森\n    ']
# 暂无
# ['剧情', '家庭']
# ['136分钟']
# 美国
# ['\n      肯尼斯·罗纳根\n    ']
# 818万
# ['喜剧', '爱情', '动作', '奇幻']
# ['110分钟']
# 中国大陆
# ['\n      刘镇伟\n    ']
# 18683万
# ['剧情']
# [' 97分钟']
# 美国
# ['\n      托尼·凯耶\n    ']
# 暂无
# ['爱情']
# ['101分钟']
# 瑞士
# ['\n      理查德·林克莱特\n    ']
# 暂无
# ['剧情', '家庭', '冒险']
# ['111分钟']
# 德国
# ['\n      阿兰·葛斯彭纳\n    ']
# 2093万
# ['剧情', '科幻', '悬疑', '惊悚']
# ['113分钟']
# 加拿大
# ['\n      埃里克·布雷斯\n    ', '\n      J·麦基·格鲁伯\n    ']
# 暂无
# ['剧情', '喜剧', '爱情']
# ['118分钟']
# 美国
# ['\n      威廉·惠勒\n    ']
# 暂无
# ['剧情', '喜剧', '犯罪']
# ['154分钟']
# 美国
# ['\n      昆汀·塔伦蒂诺\n    ']
# 暂无
# ['剧情', '喜剧']
# ['120分钟']
# 日本
# ['\n      北野武\n    ']
# 906万
# ['动作', '惊悚', '灾难']
# ['118分钟']
# 韩国
# ['\n      延尚昊\n    ', '\n      延相昊\n    ']
# 暂无
# ['剧情', '悬疑', '惊悚', '犯罪']
# ['127分钟']
# 美国
# ['\n      大卫·芬奇\n    ']
# 暂无
# ['剧情']
# [' 96分钟']
# 韩国
# ['\n      王家卫\n    ']
# 暂无
# ['剧情', '犯罪']
# ['101分钟']
# 中国香港
# ['\n      刘伟强\n    ', '\n      麦兆辉\n    ']
# 2万
# ['剧情', '爱情']
# [' 80分钟']
# 美国
# ['\n      理查德·林克莱特\n    ']
# 暂无
# ['剧情', '战争']
# [' 94分钟']
# 美国
# ['\n      马克·赫尔曼\n    ', '\n      马克·鲁赫曼\n    ']
# 暂无
# ['剧情']
# ['126分钟']
# 美国
# ['\n      格斯·范·桑特\n    ']
# 暂无
# ['剧情', '悬疑', '爱情']
# ['102分钟']
# 中国香港
# ['\n      王家卫\n    ']
# 暂无
# ['剧情', '爱情', '奇幻']
# ['105分钟']
# 美国
# ['\n      蒂姆·波顿\n    ']
# 暂无
# ['剧情']
# ['127分钟']
# 韩国
# ['\n      杨宇硕\n    ']
# 暂无

# %%
sub_list_5 = data_list[80:].copy()
for link in sub_list_5:
    scrapSubWeb(link)
# Out:
# ['剧情', '悬疑', '犯罪']
# ['116分钟']
# 美国
# ['\n      比利·怀德\n    ']
# 暂无
# ['剧情']
# ['122分钟']
# 韩国
# ['\n      李濬益\n    ', '\n      李俊益\n    ']
# 暂无
# ['剧情', '音乐', '传记']
# ['134分钟']
# 英国
# ['\n      布莱恩·辛格\n    ']
# 9907万
# ['喜剧', '爱情', '奇幻']
# ['123分钟']
# 英国
# ['\n      理查德·柯蒂斯\n    ']
# 暂无
# ['剧情', '爱情', '家庭']
# ['134分钟']
# 加拿大
# ['\n      李安\n    ']
# 暂无
# ['动画', '奇幻', '冒险']
# ['125分钟']
# 日本
# ['\n      宫崎骏\n    ']
# 暂无
# ['剧情', '悬疑']
# ['159分钟']
# 美国
# ['\n      西德尼·吕美特\n    ']
# 暂无
# ['惊悚', '剧情', '犯罪', '喜剧']
# ['107分钟']
# 英国
# ['\n      盖·里奇\n    ']
# 暂无
# ['剧情', '动作', '科幻', '惊悚']
# ['152分钟']
# 英国
# ['\n      克里斯托弗·诺兰\n    ']
# 暂无
# ['剧情', '传记', '犯罪']
# ['141分钟']
# 加拿大
# ['\n      史蒂文·斯皮尔伯格\n    ']
# 1200万
# ['剧情', '战争', '历史', '传记']
# ['139分钟']
# 美国
# ['\n      梅尔·吉布森\n    ']
# 42582万
# ['剧情', '喜剧', '爱情']
# ['135分钟']
# 法国
# ['\n      理查德·柯蒂斯\n    ']
# 暂无
# ['剧情', '家庭']
# ['113分钟']
# 美国
# ['\n      斯蒂芬·卓博斯基\n    ']
# 19151万
# ['奇幻']
# ['125分钟']
# 美国
# ['\n      蒂姆·波顿\n    ']
# 暂无
# ['剧情', '音乐', '传记', '战争']
# ['150分钟']
# 波兰
# ['\n      罗曼·波兰斯基\n    ']
# 暂无
# ['剧情', '家庭']
# ['124分钟']
# 美国
# ['\n      李安\n    ']
# 暂无
# ['剧情', '悬疑', '犯罪']
# ['102分钟']
# 美国
# ['\n      阿尼什·查甘蒂\n    ']
# 3049万
# ['剧情', '悬疑', '惊悚']
# ['130分钟']
# 英国
# ['\n      克里斯托弗·诺兰\n    ']
# 暂无
# ['剧情', '战争', '传记']
# ['114分钟']
# 英国
# ['\n      莫滕·泰杜姆\n    ']
# 5247万
# ['剧情', '悬疑', '惊悚']
# ['138分钟']
# 美国
# ['\n      马丁·斯科塞斯\n    ']
# 暂无

# %%
data_list = []
data_list = sub_list_1 + sub_list_2 + sub_list_3 + sub_list_4 + sub_list_5

# %%
data_list
# Out:
# [['1',
#   '/films/1200486',
#   '我不是药神',
#   '徐峥,周一围,王传君',
#   '2018-07-05',
#   '9.6',
#   '剧情，喜剧',
#   '117分钟',
#   '中国大陆',
#   '文牧野',
#   '310002万'],
#  ['2',
#   '/films/1297',
#   '肖申克的救赎',
#   '蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿',
#   '1994-09-10',
#   '9.5',
#   '剧情，犯罪',
#   '142分钟',
#   '美国',
#   '弗兰克·德拉邦特',
#   '暂无'],
#  ['3',
#   '/films/1206605',
#   '绿皮书',
#   '维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼',
#   '2019-03-01',
#   '9.5',
#   '剧情，喜剧，传记',
#   '130分钟',
#   '美国',
#   '彼得·法雷里',
#   '47872万'],
#  ['4',
#   '/films/1292',
#   '海上钢琴师',
#   '蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世',
#   '2019-11-15',
#   '9.3',
#   '剧情，爱情，音乐',
#   '126分钟',
#   '意大利',
#   '朱塞佩·托纳多雷',
#   '14376万'],
#  ['5',
#   '/films/1211270',
#   '哪吒之魔童降世',
#   '吕艳婷,囧森瑟夫,瀚墨',
#   '2019-07-26',
#   '9.6',
#   '动画，喜剧，奇幻',
#   '110分钟',
#   '中国大陆',
#   '饺子',
#   '66507万'],
#  ['6',
#   '/films/1203',
#   '霸王别姬',
#   '张国荣,张丰毅,巩俐',
#   '1993-07-26',
#   '9.4',
#   '剧情，爱情',
#   '171分钟',
#   '中国香港',
#   '陈凯歌',
#   '5万'],
#  ['7',
#   '/films/1216365',
#   '小偷家族',
#   '中川雅也,安藤樱,松冈茉优',
#   '2018-08-03',
#   '8.1',
#   '剧情，犯罪',
#   '121分钟',
#   '日本',
#   '是枝裕和',
#   '9675万'],
#  ['8',
#   '/films/1303',
#   '美丽人生',
#   '罗伯托·贝尼尼,朱斯蒂诺·杜拉诺,赛尔乔·比尼·布斯特里克',
#   '2020-01-03',
#   '9.3',
#   '战争，剧情，爱情',
#   '116分钟',
#   '意大利',
#   '罗伯托·贝尼尼',
#   '5979万'],
#  ['9',
#   '/films/4055',
#   '这个杀手不太冷',
#   '让·雷诺,加里·奥德曼,娜塔莉·波特曼',
#   '1994-09-14',
#   '9.4',
#   '剧情，动作，犯罪',
#   '110分钟',
#   '法国',
#   '吕克·贝松',
#   '暂无'],
#  ['10',
#   '/films/416',
#   '盗梦空间',
#   '莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特',
#   '2010-09-01',
#   '9.0',
#   '动作，悬疑，惊悚，科幻',
#   '148分钟',
#   '英国',
#   '克里斯托弗·诺兰',
#   '49620万'],
#  ['11',
#   '/films/1633',
#   '阿甘正传',
#   '汤姆·汉克斯,罗宾·怀特,加里·西尼斯',
#   '1994-07-06',
#   '9.4',
#   '剧情，爱情',
#   '142分钟',
#   '美国',
#   '罗伯特·泽米吉斯',
#   '暂无'],
#  ['12',
#   '/films/1212',
#   '千与千寻',
#   '柊瑠美,周冬雨,入野自由',
#   '2019-06-21',
#   '9.3',
#   '动画，冒险，奇幻，家庭',
#   '125分钟',
#   '日本',
#   '宫崎骏',
#   '48828万'],
#  ['13',
#   '/films/78341',
#   '星际穿越',
#   '马修·麦康纳,安妮·海瑟薇,杰西卡·查斯坦',
#   '2014-11-12',
#   '9.3',
#   '剧情，科幻，冒险',
#   '169分钟',
#   '美国',
#   '克里斯托弗·诺兰',
#   '87697万'],
#  ['14',
#   '/films/1304',
#   '楚门的世界',
#   '金·凯瑞,劳拉·琳妮,诺亚·艾默里奇',
#   '1998',
#   '8.9',
#   '剧情',
#   '103分钟',
#   '美国',
#   '彼得·威尔',
#   '暂无'],
#  ['15',
#   '/films/70976',
#   '触不可及',
#   '弗朗索瓦·克鲁塞,奥玛·希,安娜·勒尼',
#   '2011-11-02',
#   '9.1',
#   '剧情，喜剧',
#   '112分钟',
#   '法国',
#   '奥利维埃·纳卡什，埃里克·托莱达诺',
#   '暂无'],
#  ['16',
#   '/films/3667',
#   '辛德勒的名单',
#   '连姆·尼森,拉尔夫·费因斯,本·金斯利',
#   '1993-11-30',
#   '9.2',
#   '剧情，历史，战争',
#   '195分钟',
#   '美国',
#   '史蒂文·斯皮尔伯格',
#   '暂无'],
#  ['17',
#   '/films/1319',
#   '情书',
#   '中山美穗,丰川悦司,酒井美纪',
#   '1999-03-01',
#   '8.9',
#   '剧情，爱情',
#   '116分钟',
#   '日本',
#   '岩井俊二',
#   '暂无'],
#  ['18',
#   '/films/342068',
#   '寻梦环游记',
#   '安东尼·冈萨雷斯,本杰明·布拉特,盖尔·加西亚·贝纳尔',
#   '2017-11-24',
#   '9.6',
#   '动画，冒险，家庭',
#   '105分钟',
#   '美国',
#   '李·昂克里奇，阿德里安·莫利纳',
#   '123008万'],
#  ['19',
#   '/films/588362',
#   '摔跤吧！爸爸',
#   '阿米尔·汗,沙克希·坦沃,法缇玛·萨那·纱卡',
#   '2017-05-05',
#   '9.8',
#   '喜剧，动作，家庭',
#   '140分钟',
#   '印度',
#   '涅提·蒂瓦里',
#   '129932万'],
#  ['20',
#   '/films/1218727',
#   '何以为家',
#   '赞恩·阿尔·拉菲亚,约丹诺斯·希费罗,博鲁瓦蒂夫·特雷杰·班科尔',
#   '2019-04-29',
#   '9.3',
#   '剧情',
#   '116分钟',
#   '黎巴嫩',
#   '娜丁·拉巴基',
#   '37684万'],
#  ['21',
#   '/films/995',
#   '少年派的奇幻漂流',
#   '苏拉·沙玛,伊尔凡·可汗,塔布',
#   '2012-11-22',
#   '9.0',
#   '剧情，奇幻，冒险',
#   '127分钟',
#   '加拿大',
#   '李安',
#   '57288万'],
#  ['22',
#   '/films/1215201',
#   '小丑',
#   '华金·菲尼克斯,罗伯特·德尼罗,亚历克·鲍德温',
#   '2019-10-04',
#   '8.6',
#   '剧情，惊悚，犯罪',
#   '122分钟',
#   '美国',
#   '托德·菲利普斯',
#   '暂无'],
#  ['23',
#   '/films/38286',
#   '忠犬八公的故事',
#   'Forest,理查·基尔,琼·艾伦',
#   '2009-06-13',
#   '9.3',
#   '剧情',
#   ' 93分钟',
#   '英国',
#   '拉斯·霍尔斯道姆',
#   '暂无'],
#  ['24',
#   '/films/46818',
#   '怦然心动',
#   '玛德琳·卡罗尔,卡兰·麦克奥利菲,艾丹•奎因',
#   '2010-07-26',
#   '8.9',
#   '爱情',
#   ' 90分钟',
#   '美国',
#   '罗伯·莱纳',
#   '暂无'],
#  ['25',
#   '/films/267',
#   '泰坦尼克号',
#   '莱昂纳多·迪卡普里奥,凯特·温丝莱特,比利·赞恩',
#   '1998-04-03',
#   '9.4',
#   '剧情，爱情，灾难',
#   '194分钟',
#   '美国',
#   '詹姆斯·卡梅隆',
#   '130615万'],
#  ['26',
#   '/films/344881',
#   '你的名字。',
#   '上白石萌音,佟心竹,神木隆之介',
#   '2016-12-02',
#   '9.2',
#   '爱情，动画，奇幻',
#   '106分钟',
#   '日本',
#   '新海诚',
#   '57571万'],
#  ['27',
#   '/films/899',
#   '当幸福来敲门',
#   '威尔·史密斯,贾登·史密斯,坦迪·牛顿',
#   '2008-01-17',
#   '9.3',
#   '剧情，家庭，传记',
#   '117分钟',
#   '美国',
#   '加布里埃莱·穆奇诺',
#   '981万'],
#  ['28',
#   '/films/43',
#   '三傻大闹宝莱坞',
#   '阿米尔·汗,黄渤,卡琳娜·卡普',
#   '2011-12-08',
#   '9.1',
#   '剧情，喜剧，冒险',
#   '171分钟',
#   '印度',
#   '拉吉库马尔·希拉尼',
#   '1396万'],
#  ['29',
#   '/films/718',
#   '天堂电影院',
#   '菲利浦·诺瓦雷,雅克·贝汉,马克·莱昂纳蒂',
#   '2021-06-11',
#   '9.3',
#   '剧情，爱情',
#   '124分钟',
#   '意大利',
#   '朱塞佩·托纳多雷',
#   '2000万'],
#  ['30',
#   '/films/67214',
#   '熔炉',
#   '孔刘,郑有美,金智英',
#   '2011-09-22',
#   '8.8',
#   '剧情',
#   '125分钟',
#   '韩国',
#   '黄东赫',
#   '暂无'],
#  ['31',
#   '/films/1205',
#   '放牛班的春天',
#   '热拉尔·朱尼奥,让-巴蒂斯特·莫尼耶,玛丽·布奈尔',
#   '2004-10-16',
#   '8.8',
#   '剧情，喜剧，音乐',
#   ' 96分钟',
#   '瑞士',
#   '克里斯托夫·巴拉蒂',
#   '暂无'],
#  ['32',
#   '/films/123',
#   '龙猫',
#   '秦岚,糸井重里,岛本须美',
#   '2018-12-14',
#   '9.2',
#   '动画，冒险，奇幻，家庭',
#   ' 86分钟',
#   '日本',
#   '宫崎骏',
#   '17370万'],
#  ['33',
#   '/films/458721',
#   '看不见的客人',
#   '马里奥·卡萨斯,阿娜·瓦格纳,何塞·科罗纳多',
#   '2017-09-15',
#   '9.4',
#   '犯罪，悬疑，惊悚',
#   '106分钟',
#   '西班牙',
#   '奥里奥尔·保罗',
#   '17258万'],
#  ['34',
#   '/films/1247',
#   '教父',
#   '马龙·白兰度,阿尔·帕西诺,詹姆斯·肯恩',
#   '2015-04-18',
#   '9.3',
#   '剧情，惊悚，犯罪',
#   '175分钟',
#   '美国',
#   '弗朗西斯·福特·科波拉',
#   '暂无'],
#  ['35',
#   '/films/341178',
#   '头号玩家',
#   '泰伊·谢里丹,奥利维亚·库克,本·门德尔森',
#   '2018-03-30',
#   '9.0',
#   '动作，冒险，科幻',
#   '140分钟',
#   '美国',
#   '史蒂文·斯皮尔伯格',
#   '139668万'],
#  ['36',
#   '/films/20394',
#   '被嫌弃的松子的一生',
#   '中谷美纪,永山瑛太,伊势谷友介',
#   '2006-05-27',
#   '8.5',
#   '剧情，歌舞',
#   '130分钟',
#   '日本',
#   '中岛哲也，酒井圣博',
#   '暂无'],
#  ['37',
#   '/films/1375',
#   '活着',
#   '葛优,巩俐,牛犇',
#   '1994-05-17',
#   '9.0',
#   '剧情，家庭，历史',
#   '132分钟',
#   '中国香港',
#   '张艺谋',
#   '暂无'],
#  ['38',
#   '/films/342754',
#   '三块广告牌',
#   '弗兰西斯·麦克多蒙德,伍迪·哈里森,山姆·洛克威尔',
#   '2018-03-02',
#   '8.6',
#   '剧情，犯罪',
#   '115分钟',
#   '美国',
#   '马丁·麦克唐纳',
#   '6499万'],
#  ['39',
#   '/films/409801',
#   '请以你的名字呼唤我',
#   '提莫西·查拉梅,艾米·汉莫,迈克尔·斯图巴',
#   '2017-01-22',
#   '8.0',
#   '爱情，剧情',
#   '132分钟',
#   '德国',
#   '卢卡·瓜达尼诺',
#   '暂无'],
#  ['40',
#   '/films/1204',
#   '死亡诗社',
#   '罗宾·威廉姆斯,伊桑·霍克,柯特伍德·史密斯',
#   '1989-06-02',
#   '8.7',
#   '剧情',
#   '128分钟',
#   '美国',
#   '彼得·威尔',
#   '暂无'],
#  ['41',
#   '/films/6289',
#   '闻香识女人',
#   '阿尔·帕西诺,克里斯·奥唐纳,加布里埃尔·安瓦尔',
#   '1992-12-23',
#   '8.8',
#   '剧情',
#   '157分钟',
#   '美国',
#   '马丁·布莱斯特',
#   '暂无'],
#  ['42',
#   '/films/246286',
#   '疯狂动物城',
#   '金妮弗·古德温,杰森·贝特曼,伊德瑞斯·艾尔巴',
#   '2016-03-04',
#   '9.5',
#   '动画，动作，冒险',
#   '109分钟',
#   '美国',
#   '拜伦·霍华德，瑞奇·摩尔',
#   '153190万'],
#  ['43',
#   '/films/488',
#   '机器人总动员',
#   '本·贝尔特,艾丽莎·奈特,杰夫·格尔林',
#   '2008-06-27',
#   '9.3',
#   '喜剧，科幻，动画',
#   ' 98分钟',
#   '美国',
#   '安德鲁·斯坦顿',
#   '暂无'],
#  ['44',
#   '/films/248172',
#   '复仇者联盟4：终局之战',
#   '小罗伯特·唐尼,克里斯·埃文斯,马克·鲁法洛',
#   '2019-04-24',
#   '9.1',
#   '动作，冒险，奇幻',
#   '181分钟',
#   '美国',
#   '乔·罗素，安东尼·罗素',
#   '425013万'],
#  ['45',
#   '/films/2039',
#   '末代皇帝',
#   '尊龙,陈冲,彼得·奥图尔',
#   '1987-10-04',
#   '8.8',
#   '剧情',
#   '163分钟',
#   '美国',
#   '贝纳尔多·贝托鲁奇',
#   '暂无'],
#  ['46',
#   '/films/1284164',
#   '西西里的美丽传说',
#   '莫妮卡·安娜·玛丽亚·贝鲁奇,朱塞佩·苏尔法罗,玛蒂尔德·皮亚纳',
#   '2000-10-26',
#   '8.2',
#   '剧情，爱情，战争',
#   '109分钟',
#   '意大利',
#   '朱塞佩·托纳多雷',
#   '暂无'],
#  ['47',
#   '/films/553231',
#   '心灵奇旅',
#   '杰米·福克斯,蒂娜·菲,菲利西亚·拉斯海德',
#   '2020-12-25',
#   '9.2',
#   '动画，喜剧，冒险',
#   '101分钟',
#   '美国',
#   '彼特·道格特，坎普·鲍尔斯',
#   '37618万'],
#  ['48',
#   '/films/182',
#   '让子弹飞',
#   '姜文,周润发,葛优',
#   '2010-12-16',
#   '8.5',
#   '剧情，喜剧，动作，西部',
#   '132分钟',
#   '中国香港',
#   '姜文',
#   '63675万'],
#  ['49',
#   '/films/18318',
#   '本杰明·巴顿奇事',
#   '布拉德·皮特,凯特·布兰切特,塔拉吉·P·汉森',
#   '2008-12-25',
#   '8.8',
#   '剧情，爱情，奇幻',
#   '166分钟',
#   '美国',
#   '大卫·芬奇',
#   '暂无'],
#  ['50',
#   '/films/1291',
#   '搏击俱乐部',
#   '爱德华·哈里森·诺顿,布拉德·皮特,海伦娜·伯翰·卡特',
#   '1999-09-10',
#   '8.8',
#   '剧情，动作，悬疑，惊悚',
#   '139分钟',
#   '德国',
#   '大卫·芬奇',
#   '暂无'],
#  ['51',
#   '/films/243',
#   '阿凡达',
#   '萨姆·沃辛顿,佐伊·索尔达娜,米歇尔·罗德里格兹',
#   '2010-01-04',
#   '9.4',
#   '动作，科幻，冒险',
#   '162分钟',
#   '英国',
#   '詹姆斯·卡梅隆',
#   '暂无'],
#  ['52',
#   '/films/1332',
#   '美国往事',
#   '罗伯特·德尼罗,詹姆斯·伍兹,伊丽莎白·麦戈文',
#   '2015-04-23',
#   '9.1',
#   '剧情，犯罪',
#   '229分钟',
#   '美国',
#   '赛尔乔·莱翁内',
#   '暂无'],
#  ['53',
#   '/films/23127',
#   '窃听风暴',
#   '乌尔里希·穆埃,塞巴斯蒂安·科赫,马蒂娜·格德克',
#   '2006-03-23',
#   '9.0',
#   '剧情，悬疑',
#   '137分钟',
#   '德国',
#   '弗洛里安·亨克尔·冯·多纳斯马尔克',
#   '暂无'],
#  ['54',
#   '/films/614',
#   '飞屋环游记',
#   '爱德华·阿斯纳,乔丹·长井,鲍勃·彼德森',
#   '2009-08-04',
#   '8.9',
#   '剧情，喜剧，动画，冒险',
#   ' 96分钟',
#   '美国',
#   '彼特·道格特，鲍勃·彼德森',
#   '7906万'],
#  ['55',
#   '/films/1314',
#   '天使爱美丽',
#   '奥黛丽·塔图,马修·卡索维茨,吕菲斯',
#   '2001-04-25',
#   '8.4',
#   '爱情',
#   '122分钟',
#   '德国',
#   '让-皮埃尔·热内',
#   '暂无'],
#  ['56',
#   '/films/7431',
#   '乱世佳人',
#   '费雯·丽,克拉克·盖博,奥利维娅·德哈维兰',
#   '1939-12-15',
#   '9.1',
#   '剧情，爱情，历史，战争',
#   '238分钟',
#   '美国',
#   '乔治·库克，维克多·弗莱明',
#   '暂无'],
#  ['57',
#   '/films/1322',
#   '飞越疯人院',
#   '杰克·尼科尔森,路易丝·弗莱彻,威尔·萨姆森',
#   '1975-11-19',
#   '8.8',
#   '剧情',
#   '133分钟',
#   '美国',
#   '米洛斯·福尔曼',
#   '暂无'],
#  ['58',
#   '/films/1383',
#   '一一',
#   '吴念真,金燕玲,李凯莉',
#   '2017-07-28',
#   '8.9',
#   '剧情，爱情，家庭',
#   '173分钟',
#   '日本',
#   '杨德昌',
#   '暂无'],
#  ['59',
#   '/films/11473',
#   '美丽心灵',
#   '罗素·克劳,詹妮弗·康纳利,艾德·哈里斯',
#   '2001-12-13',
#   '8.8',
#   '剧情，传记',
#   '135分钟',
#   '美国',
#   '朗·霍华德',
#   '暂无'],
#  ['60',
#   '/films/78997',
#   '消失的爱人',
#   '本·阿弗莱克,裴淳华,尼尔·帕特里克·哈里斯',
#   '2014-09-26',
#   '8.7',
#   '剧情，悬疑，惊悚，犯罪',
#   '149分钟',
#   '美国',
#   '大卫·芬奇',
#   '暂无'],
#  ['61',
#   '/films/78449',
#   '布达佩斯大饭店',
#   '拉尔夫·费因斯,托尼·雷沃罗利,西尔莎·罗南',
#   '2014-06-14',
#   '8.7',
#   '剧情，喜剧，冒险',
#   '100分钟',
#   '英国',
#   '韦斯·安德森',
#   '暂无'],
#  ['62',
#   '/films/338365',
#   '海边的曼彻斯特',
#   '卡西·阿弗莱克,卢卡斯·赫奇斯,米歇尔·威廉姆斯',
#   '2017-08-25',
#   '8.8',
#   '剧情，家庭',
#   '136分钟',
#   '美国',
#   '肯尼斯·罗纳根',
#   '818万'],
#  ['63',
#   '/films/158',
#   '大话西游之大圣娶亲',
#   '周星驰,朱茵,莫文蔚',
#   '2014-10-24',
#   '8.8',
#   '喜剧，爱情，动作，奇幻',
#   '110分钟',
#   '中国大陆',
#   '刘镇伟',
#   '18683万'],
#  ['64',
#   '/films/65496',
#   '超脱',
#   '艾德里安·布洛迪,马西娅·盖伊·哈登,詹姆斯·肯恩',
#   '2011-04-25',
#   '8.7',
#   '剧情',
#   ' 97分钟',
#   '美国',
#   '托尼·凯耶',
#   '暂无'],
#  ['65',
#   '/films/4587',
#   '爱在黎明破晓前',
#   '伊桑·霍克,朱莉·德尔佩,安德莉亚·埃克特',
#   '1995-01-27',
#   '8.7',
#   '爱情',
#   '101分钟',
#   '瑞士',
#   '理查德·林克莱特',
#   '暂无'],
#  ['66',
#   '/films/337625',
#   '海蒂和爷爷',
#   '阿努克·斯特芬 ,布鲁诺·甘茨,昆林·艾格匹',
#   '2019-05-16',
#   '9.5',
#   '剧情，家庭，冒险',
#   '111分钟',
#   '德国',
#   '阿兰·葛斯彭纳',
#   '2093万'],
#  ['67',
#   '/films/1368',
#   '蝴蝶效应',
#   '约翰·帕特里克·阿梅多利,罗根·勒曼,卡梅隆·布莱特',
#   '2004-01-23',
#   '8.7',
#   '剧情，科幻，悬疑，惊悚',
#   '113分钟',
#   '加拿大',
#   '埃里克·布雷斯，J·麦基·格鲁伯',
#   '暂无'],
#  ['68',
#   '/films/2641',
#   '罗马假日',
#   '格利高里·派克,奥黛丽·赫本,埃迪·艾伯特',
#   '1953-08-20',
#   '9.1',
#   '剧情，喜剧，爱情',
#   '118分钟',
#   '美国',
#   '威廉·惠勒',
#   '暂无'],
#  ['69',
#   '/films/1239',
#   '低俗小说',
#   '约翰·特拉沃尔塔,乌玛·瑟曼,塞缪尔·杰克逊',
#   '1994-05-21',
#   '8.7',
#   '剧情，喜剧，犯罪',
#   '154分钟',
#   '美国',
#   '昆汀·塔伦蒂诺',
#   '暂无'],
#  ['70',
#   '/films/2212',
#   '菊次郎的夏天',
#   '北野武,关口雄介,岸本 加世子',
#   '2020-09-25',
#   '8.8',
#   '剧情，喜剧',
#   '120分钟',
#   '日本',
#   '北野武',
#   '906万'],
#  ['71',
#   '/films/343203',
#   '釜山行',
#   '孔刘,郑有美,马东锡',
#   '2016-05-13',
#   '8.9',
#   '动作，惊悚，灾难',
#   '118分钟',
#   '韩国',
#   '延尚昊，延相昊',
#   '暂无'],
#  ['72',
#   '/films/1321',
#   '七宗罪',
#   '布拉德·皮特,摩根·弗里曼,格温妮斯·帕特洛',
#   '1995-09-22',
#   '8.7',
#   '剧情，悬疑，惊悚，犯罪',
#   '127分钟',
#   '美国',
#   '大卫·芬奇',
#   '暂无'],
#  ['73',
#   '/films/1597',
#   '春光乍泄',
#   '张国荣,梁朝伟,张震',
#   '1997-05-30',
#   '9.2',
#   '剧情',
#   ' 96分钟',
#   '韩国',
#   '王家卫',
#   '暂无'],
#  ['74',
#   '/films/224973',
#   '无间道',
#   '刘德华,梁朝伟,黄秋生',
#   '2003-09-05',
#   '9.1',
#   '剧情，犯罪',
#   '101分钟',
#   '中国香港',
#   '刘伟强，麦兆辉',
#   '2万'],
#  ['75',
#   '/films/1287',
#   '爱在日落黄昏时',
#   '伊桑·霍克,朱莉·德尔佩,弗农·多布切夫',
#   '2015-04-20',
#   '8.7',
#   '剧情，爱情',
#   ' 80分钟',
#   '美国',
#   '理查德·林克莱特',
#   '暂无'],
#  ['76',
#   '/films/38099',
#   '穿条纹睡衣的男孩',
#   '阿沙·巴特菲尔德,维拉·法梅加,大卫·休里斯',
#   '2008-08-28',
#   '9.0',
#   '剧情，战争',
#   ' 94分钟',
#   '美国',
#   '马克·赫尔曼，马克·鲁赫曼',
#   '暂无'],
#  ['77',
#   '/films/1575',
#   '心灵捕手',
#   '罗宾·威廉姆斯,马特·达蒙,明妮·德里弗',
#   '1997-12-05',
#   '8.4',
#   '剧情',
#   '126分钟',
#   '美国',
#   '格斯·范·桑特',
#   '暂无'],
#  ['78',
#   '/films/1290',
#   '重庆森林',
#   '梁朝伟,王菲,金城武',
#   '1994-07-14',
#   '8.6',
#   '剧情，悬疑，爱情',
#   '102分钟',
#   '中国香港',
#   '王家卫',
#   '暂无'],
#  ['79',
#   '/films/513',
#   '剪刀手爱德华',
#   '约翰尼·德普,薇诺娜·瑞德,黛安娜·维斯特',
#   '1990-12-06',
#   '8.8',
#   '剧情，爱情，奇幻',
#   '105分钟',
#   '美国',
#   '蒂姆·波顿',
#   '暂无'],
#  ['80',
#   '/films/246433',
#   '辩护人',
#   '宋康昊,郭度沅,吴达洙',
#   '2013-12-18',
#   '8.8',
#   '剧情',
#   '127分钟',
#   '韩国',
#   '杨宇硕',
#   '暂无'],
#  ['81',
#   '/films/4430',
#   '控方证人',
#   '泰隆·鲍华,玛琳·黛德丽,查尔斯·劳顿',
#   '1957-12-17',
#   '8.5',
#   '剧情，悬疑，犯罪',
#   '116分钟',
#   '美国',
#   '比利·怀德',
#   '暂无'],
#  ['82',
#   '/films/78538',
#   '素媛',
#   '李甄,薛耿求,严智苑',
#   '2013-10-02',
#   '9.1',
#   '剧情',
#   '122分钟',
#   '韩国',
#   '李濬益，李俊益',
#   '暂无'],
#  ['83',
#   '/films/1167831',
#   '波西米亚狂想曲',
#   '拉米·马雷克,本·哈迪,约瑟夫•梅泽罗',
#   '2019-03-22',
#   '9.4',
#   '剧情，音乐，传记',
#   '134分钟',
#   '英国',
#   '布莱恩·辛格',
#   '9907万'],
#  ['84',
#   '/films/78312',
#   '时空恋旅人',
#   '瑞秋·麦克亚当斯,多姆纳尔·格里森,比尔·奈伊',
#   '2013-09-04',
#   '8.9',
#   '喜剧，爱情，奇幻',
#   '123分钟',
#   '英国',
#   '理查德·柯蒂斯',
#   '暂无'],
#  ['85',
#   '/films/14652',
#   '断背山',
#   '希斯·莱杰,杰克·吉伦哈尔,米歇尔·威廉姆斯',
#   '2005-09-02',
#   '8.9',
#   '剧情，爱情，家庭',
#   '134分钟',
#   '加拿大',
#   '李安',
#   '暂无'],
#  ['86',
#   '/films/1228',
#   '天空之城',
#   '寺田农,鹫尾真知子,龟山助清',
#   '1992-05-01',
#   '9.0',
#   '动画，奇幻，冒险',
#   '125分钟',
#   '日本',
#   '宫崎骏',
#   '暂无'],
#  ['87',
#   '/films/2049',
#   '十二怒汉',
#   '亨利·方达,李·科布,马丁·鲍尔萨姆',
#   '1957-04-13',
#   '9.1',
#   '剧情，悬疑',
#   '159分钟',
#   '美国',
#   '西德尼·吕美特',
#   '暂无'],
#  ['88',
#   '/films/2204',
#   '两杆大烟枪',
#   '杰森·弗莱明,德克斯特·弗莱彻,杰森•斯坦森',
#   '1998-08-28',
#   '8.7',
#   '惊悚，剧情，犯罪，喜剧',
#   '107分钟',
#   '英国',
#   '盖·里奇',
#   '暂无'],
#  ['89',
#   '/films/790',
#   '蝙蝠侠：黑暗骑士',
#   '克里斯蒂安·贝尔,希斯·莱杰,阿伦·伊克哈特',
#   '2008-07-14',
#   '9.3',
#   '剧情，动作，科幻，惊悚',
#   '152分钟',
#   '英国',
#   '克里斯托弗·诺兰',
#   '暂无'],
#  ['90',
#   '/films/11105',
#   '猫鼠游戏',
#   '莱昂纳多·迪卡普里奥,汤姆·汉克斯,克里斯托弗·沃肯',
#   '2003-04-11',
#   '8.6',
#   '剧情，传记，犯罪',
#   '141分钟',
#   '加拿大',
#   '史蒂文·斯皮尔伯格',
#   '1200万'],
#  ['91',
#   '/films/338349',
#   '血战钢锯岭',
#   '安德鲁·加菲尔德,雨果·维文,卢克·布雷西',
#   '2016-12-08',
#   '9.3',
#   '剧情，战争，历史，传记',
#   '139分钟',
#   '美国',
#   '梅尔·吉布森',
#   '42582万'],
#  ['92',
#   '/films/1379',
#   '真爱至上',
#   '休·格兰特,比尔·奈伊,连姆·尼森',
#   '2003-11-21',
#   '8.6',
#   '剧情，喜剧，爱情',
#   '135分钟',
#   '法国',
#   '理查德·柯蒂斯',
#   '暂无'],
#  ['93',
#   '/films/672130',
#   '奇迹男孩',
#   '雅各布·特瑞布雷,朱莉娅·罗伯茨,欧文·威尔逊',
#   '2018-01-19',
#   '9.2',
#   '剧情，家庭',
#   '113分钟',
#   '美国',
#   '斯蒂芬·卓博斯基',
#   '19151万'],
#  ['94',
#   '/films/1202',
#   '大鱼',
#   '伊万·麦克格雷格,阿尔伯特·芬尼,杰西卡·兰格',
#   '2003-12-04',
#   '8.6',
#   '奇幻',
#   '125分钟',
#   '美国',
#   '蒂姆·波顿',
#   '暂无'],
#  ['95',
#   '/films/4883',
#   '钢琴家',
#   '艾德里安·布洛迪,艾米莉娅·福克斯,米哈乌·热布罗夫斯基',
#   '2002-05-24',
#   '8.9',
#   '剧情，音乐，传记，战争',
#   '150分钟',
#   '波兰',
#   '罗曼·波兰斯基',
#   '暂无'],
#  ['96',
#   '/films/1233',
#   '饮食男女',
#   '郎雄,吴倩莲,杨贵媚',
#   '1994-08-03',
#   '8.8',
#   '剧情，家庭',
#   '124分钟',
#   '美国',
#   '李安',
#   '暂无'],
#  ['97',
#   '/films/1219776',
#   '网络谜踪',
#   '约翰·赵,米切尔·拉,黛博拉·梅辛',
#   '2018-12-14',
#   '8.6',
#   '剧情，悬疑，犯罪',
#   '102分钟',
#   '美国',
#   '阿尼什·查甘蒂',
#   '3049万'],
#  ['98',
#   '/films/20131',
#   '致命魔术',
#   '休·杰克曼,克里斯蒂安·贝尔,迈克尔·凯恩',
#   '2006-10-17',
#   '8.8',
#   '剧情，悬疑，惊悚',
#   '130分钟',
#   '英国',
#   '克里斯托弗·诺兰',
#   '暂无'],
#  ['99',
#   '/films/78646',
#   '模仿游戏',
#   '本尼迪克特·康伯巴奇,凯拉·奈特莉,马修·古迪',
#   '2015-07-21',
#   '9.3',
#   '剧情，战争，传记',
#   '114分钟',
#   '英国',
#   '莫滕·泰杜姆',
#   '5247万'],
#  ['100',
#   '/films/907',
#   '禁闭岛',
#   '莱昂纳多·迪卡普里奥,马克·鲁法洛,本·金斯利',
#   '2010-02-13',
#   '8.7',
#   '剧情，悬疑，惊悚',
#   '138分钟',
#   '美国',
#   '马丁·斯科塞斯',
#   '暂无']]

# %%
with open('Tianlei_Shi+1824152.csv', 'w', newline='', encoding='utf-8-sig') as csvfile:
    writer  = csv.writer(csvfile)
    headers = ['Rank', 'Title', 'Name of actors', 'Release date', 'Rating', 'Type', 'Duration', 'Region', 'Name of director', 'Cumulative income']
    writer.writerow(headers)
    for row in data_list:
        row = [row[0]] + row[2:]
        writer.writerow(row)

# %% [markdown]
# ## Data Analysis

# %%
data = pd.read_csv("Tianlei_Shi+1824152.csv")
data.head(10)
# Out:
#    Rank    Title                 Name of actors Release date  Rating  \
# 0     1    我不是药神                     徐峥,周一围,王传君     2018/7/5     9.6
# 1     2   肖申克的救赎            蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿    1994/9/10     9.5
# 2     3      绿皮书         维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼     2019/3/1     9.5
# 3     4    海上钢琴师       蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世   2019/11/15     9.3
# 4     5  哪吒之魔童降世                    吕艳婷,囧森瑟夫,瀚墨    2019/7/26     9.6
# 5     6     霸王别姬                     张国荣,张丰毅,巩俐    1993/7/26     9.4
# 6     7     小偷家族                  中川雅也,安藤樱,松冈茉优     2018/8/3     8.1
# 7     8     美丽人生  罗伯托·贝尼尼,朱斯蒂诺·杜拉诺,赛尔乔·比尼·布斯特里克     2020/1/3     9.3
# 8     9  这个杀手不太冷            让·雷诺,加里·奥德曼,娜塔莉·波特曼    1994/9/14     9.4
# 9    10     盗梦空间      莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特     2010/9/1     9.0
#
#           Type Duration Region Name of director Cumulative income
# 0        剧情，喜剧    117分钟   中国大陆              文牧野           310002万
# 1        剧情，犯罪    142分钟     美国         弗兰克·德拉邦特                暂无
# 2     剧情，喜剧，传记    130分钟     美国           彼得·法雷里            47872万
# 3     剧情，爱情，音乐    126分钟    意大利         朱塞佩·托纳多雷            14376万
# 4     动画，喜剧，奇幻    110分钟   中国大陆               饺子            66507万
# 5        剧情，爱情    171分钟   中国香港              陈凯歌                5万
# 6        剧情，犯罪    121分钟     日本             是枝裕和             9675万
# 7     战争，剧情，爱情    116分钟    意大利          罗伯托·贝尼尼             5979万
# 8     剧情，动作，犯罪    110分钟     法国            吕克·贝松                暂无
# 9  动作，悬疑，惊悚，科幻    148分钟     英国         克里斯托弗·诺兰            49620万

# %%
data.describe()
# Out:
#              Rank      Rating
# count  100.000000  100.000000
# mean    50.500000    8.980000
# std     29.011492    0.348445
# min      1.000000    8.000000
# 25%     25.750000    8.700000
# 50%     50.500000    8.950000
# 75%     75.250000    9.300000
# max    100.000000    9.800000

# %%
# Region (Country) distribution

plt.figure(figsize=(10,10))
plt.rcParams['font.sans-serif']=['SimHei']
country = data.groupby('Region')['Region'].count()

patches,l_text,p_text = plt.pie(list(country), labels=list(country.index), autopct='%1.1f%%', counterclock=False)
for t in p_text:
    t.set_size(15)

for t in l_text:
    t.set_size(20)
    
plt.axis('equal') 
plt.title('Region/Country distribution')
plt.savefig("image\\region distribution.png", dpi=200, bbox_inches='tight')

# %%
# Movie Type Word Cloud

from pyecharts.globals import CurrentConfig, NotebookType  
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

from pyecharts import options as opts
from pyecharts.charts import WordCloud

type_list = []
for i in data['Type']:
    if '，' in i:
        temp = i.split('，')
        type_list += temp
    else:
        type_list.append(i)
# print(type_list, len(type_list))

type_count = Counter(type_list)
# print (dict(type_count))

name = []
value = []
for i in type_count.keys():
    name.append(i)
    value.append(type_count[i])
# print(name, value)

words=[(i,j) for i ,j in zip(name,value)]
worldcloud=(
     WordCloud()
     .add("", words, word_size_range=[20, 200])
     .set_global_opts(title_opts=opts.TitleOpts(title="Movie Type Word Cloud"))
     )

worldcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="92df4c06587a4fef8732bddfadaa52af" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_92df4c06587a4fef8732bddfadaa52af = echarts.init(
#                     document.getElementById('92df4c06587a4fef8732bddfadaa52af'), 'white', {renderer: 'canvas'});
#                 var option_92df4c06587a4fef8732bddfadaa52af = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 200
#             ],
#             "data": [
#                 {
#                     "name": "\u5267\u60c5",
#                     "value": 78,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(118,125,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u5267",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,33,31)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72af\u7f6a",
#                     "value": 16,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,36,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f20\u8bb0",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,52,7)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7231\u60c5",
#                     "value": 24,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,82,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u97f3\u4e50",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,110,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52a8\u753b",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,27,112)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5947\u5e7b",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,108,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6218\u4e89",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,30,32)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52a8\u4f5c",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(69,54,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u60ac\u7591",
#                     "value": 13,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,111,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u60ca\u609a",
#                     "value": 13,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,63,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u79d1\u5e7b",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,155,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5192\u9669",
#                     "value": 15,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,24,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5bb6\u5ead",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(83,67,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5386\u53f2",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,143,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u707e\u96be",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,153,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b4c\u821e",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,22,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u897f\u90e8",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,121,58)"
#                         }
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Movie Ty

# %%
# show the wordcloud get from above

from PIL import Image

display(Image.open('image\\Movie Type Word Cloud.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1185x620 at 0x26EC4DEC430>

# %%
# Release year distribution of movies

date_list = []
for i in data['Release date']:
    if '/' in i:
        temp = i.split('/')[0]
        date_list.append(int(temp))
    else:
        date_list.append(int(i))
# print(date_list, len(date_list))

date_count = Counter(date_list)
# print (dict(date_count))

date = []
count = []
for i in sorted(date_count.keys()):
    date.append(i)
    count.append(date_count[i])
# print(date, count)

plt.figure(figsize=(15, 10), dpi=80)

plt.plot(date, count)
plt.title('Release year statistics of movies', fontsize=20)
plt.xlabel('Release Year', fontsize=15)
plt.grid(alpha=0.9)
plt.savefig("image\\Release year statistics of movies.png", dpi=200, bbox_inches='tight')

# %%
# Cumulative income of directors

director_income = data[['Name of director', 'Cumulative income']]
# print(director_income['Name of director'])

director_dict = {}

for indexs in director_income.index:
    name, value = director_income.loc[indexs].values
    if value == '暂无':
        continue
    else:
        if '，' in name:
            name = name.split('，')
            for i in name:
                if i in director_dict:
                    director_dict[i] = director_dict[i] + int(value[:-1])
                else:
                    director_dict[i] = int(value[:-1])
        else:
            if name in director_dict:
                director_dict[name] = director_dict[name] + int(value[:-1])
            else:
                director_dict[name] = int(value[:-1])

people = []
performance = []
for i in director_dict.keys():
    people.append(i)
    performance.append(director_dict[i])
# print(people, performance)

plt.rcdefaults()
fig, ax = plt.subplots(figsize=(16, 20))

plt.rcParams['font.sans-serif']=['SimHei']

y_pos = np.arange(len(people))

total_width, n = 0.8, 2
width = total_width / n
y_pos=y_pos - (total_width - width) / 2

b = ax.barh(y_pos, performance, align='center', color='green', ecolor='black', height=0.6)
for rect in b:
    w=rect.get_width()
    ax.text(w,rect.get_y()+rect.get_height()/2,'%1.1f'%w,ha='left',va='center')

ax.set_yticks(y_pos+width/2.0)
ax.set_yticklabels(people)
ax.invert_yaxis()
ax.set_xlabel('Cumulative Income (million yuan)', fontsize=20)
ax.set_title('Cumulative income of directors', fontsize=15)
plt.savefig("image\\Cumulative income of directors.png", dpi=200, bbox_inches='tight')

# %%
# Duration distribution of movies

time = []
for i in data['Duration']:
    time.append(int(i[:-2]))

plt.hist(time, range(min(time), max(time) + 10, 10), density=True, color="#33ffff")

plt.xticks(range(min(time), max(time) + 10, 10))
plt.grid(alpha=0.4)

plt.title('Duration distribution of movies', fontsize=20)
plt.xlabel('Duration', fontsize=15)
plt.ylabel('Proportion', fontsize=15)
plt.savefig("image\\Duration distribution of movies.png", dpi=200, bbox_inches='tight')

# %%
# Relationship between rating, type, and income

types = type_count.keys()
type_convert = {}
type_value = 0
for i in types:
    type_convert[i] = type_value
    type_value += 1
# print(type_convert)

dataset = data[['Rating', 'Type', 'Cumulative income']]
Point = []

for indexs in dataset.index:
    x, y, z = dataset.loc[indexs].values
    if z == '暂无':
        continue
    else:
        if '，' in y:
            for i in y.split('，'):
                Point.append([float(x), type_convert[i], int(z[:-1])])
        else:
            Point.append([float(x), type_convert[y], int(z[:-1])])
# print(Point)

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']

fig = plt.figure(figsize=(20, 20))
ax = fig.gca(projection='3d')

X, Y, Z = [a[0] for a in Point], [b[1] for b in Point], [c[2] for c in Point]
# print(X, Y, Z, len(X), len(Y), len(Z))

ax.scatter(X, Y, Z, s=50, marker='o', color='#FF2D2D')
plt.yticks(range(len(types)), types)

plt.title('Relationship between rating, type, and cumulative income', fontsize=20)
# plt.xlabel('Rating', fontsize=15)
# plt.ylabel('Type', fontsize=15, rotation=50)
plt.savefig("image\\Relationship between rating, type, and cumulative income.png", dpi=200, bbox_inches='tight')

# %%
# Relationship between rank, rating, and income

ds = data[['Rank', 'Rating', 'Cumulative income']]
Point = []

for indexs in ds.index:
    x, y, z = ds.loc[indexs].values
    if z == '暂无':
        continue
    else:
        Point.append([int(x), float(y), int(z[:-1])])
# print(Point)

fig = plt.figure(figsize=(15, 15))

# first figure
ax = fig.add_subplot(1, 2, 1, projection='3d')

X, Y, Z = [a[1] for a in Point], [b[0] for b in Point], [c[2] for c in Point]
# print(X, Y, Z, len(X), len(Y), len(Z))

ax.scatter3D(X, Y, Z, cmap='Blues')
ax.plot3D(X, Y, Z, 'gray')

plt.title('Oiginal Figure', fontsize=20)
plt.xlabel('Rating', fontsize=15)
plt.ylabel('Rank', fontsize=15, rotation=50)

# second figure
ax = fig.add_subplot(1, 2, 2, projection='3d')

x_z = [min(X)-0.5]*len(X)
y_z = [max(Y)+0.5]*len(Y)
x_y = [min(Z)-0.5]*len(Z)

ax.plot(x_z, Y, Z)
ax.plot(X, y_z, Z)
ax.plot(X, Y, x_y)

plt.title('Projection Figure', fontsize=20)
plt.xlabel('Rating', fontsize=15)
plt.ylabel('Rank', fontsize=15, rotation=50)

plt.savefig("image\\Relationship between rank, rating, and income.png", dpi=200, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c59a97089979> in <module>
#       1 # Relationship between rank, rating, and income
#       2
# ----> 3 ds = data[['Rank', 'Rating', 'Cumulative income']]
#       4 Point = []
#       5
#
# NameError: name 'data' is not defined

# %%
Point = [[5, 1, 3], [8, 3, 5], [8, 7, 2], [5, 9, 2], [1, 8, 3], [2, 5, 2], [5, 1, 3]]
x_y = [1.7, 1.7, 1.7, 1.7, 1.7, 1.7, 1.7]

fig = plt.figure(figsize=(15, 15))

# first figure
ax = fig.gca(projection='3d')

X, Y, Z = [a[0] for a in Point], [b[1] for b in Point], [c[2] for c in Point]

ax.scatter3D(X, Y, Z, cmap='green')

ax.text(5.3, 1, 3,'V1 (x1,y1,z1)',family='monospace',fontsize=16,color='green')
ax.text(8, 3, 5.1,'V2 (x2,y2,z2)',family='monospace',fontsize=16,color='green')
ax.text(7.4, 7, 2.6,'V3 (x3,y3,z3)',family='monospace',fontsize=16,color='green')
ax.text(3.3, 8, 1.4,'V4 (x4,y4,z4)',family='monospace',fontsize=16,color='green')
ax.text(1, 8, 3.1,'V5 (x5,y5,z5)',family='monospace',fontsize=16,color='green')
ax.text(2, 0.9, 3,'V6 (x6,y6,z6)',family='monospace',fontsize=16,color='green')

ax.plot(X, Y, x_y, label='projection')
ax.plot3D(X, Y, Z,label='blue-green algae',color='green')

for i in range(len(X)):
    ax.plot([X[i], X[i]], [Y[i], Y[i]], [Z[i], x_y[i]], c='black', linestyle='--')

plt.legend()
